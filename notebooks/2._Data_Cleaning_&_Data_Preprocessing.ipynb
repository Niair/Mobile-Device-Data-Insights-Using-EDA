# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../data/raw/smartphones.csv")

# %%
data.sample(6)
# Out:
#                                         model    price  rating  \
# 193                              Nokia N73 5G  ₹46,999     NaN
# 104                      OPPO F19 Pro Plus 5G  ₹19,990    82.0
# 1010  Realme Narzo 50i Prime (4GB RAM + 64GB)   ₹8,720    64.0
# 806                          Realme GT Neo 4T  ₹29,999    80.0
# 151                         Motorola Moto G52  ₹11,999    75.0
# 968                                  Honor 50  ₹32,990    85.0
#
#                                            sim  \
# 193         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 104         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1010            Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 806   Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi
# 151        Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 968    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                            processor  \
# 193   Snapdragon  8 Gen1, Octa Core, 3 GHz Processor
# 104    Dimensity 800U , Octa Core, 2.4 GHz Processor
# 1010       Tiger T612, Octa Core, 1.82 GHz Processor
# 806    Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 151     Snapdragon 680, Octa Core, 2.4 GHz Processor
# 968    Snapdragon 778G, Octa Core, 2.4 GHz Processor
#
#                             ram                                   battery  \
# 193   12 GB RAM, 256 GB inbuilt   6000 mAh Battery with 65W Fast Charging
# 104    8 GB RAM, 128 GB inbuilt   4310 mAh Battery with 50W Fast Charging
# 1010    4 GB RAM, 64 GB inbuilt   5000 mAh Battery with 10W Fast Charging
# 806    8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 120W Fast Charging
# 151     4 GB RAM, 64 GB inbuilt   5000 mAh Battery with 33W Fast Charging
# 968    6 GB RAM, 128 GB inbuilt   4300 mAh Battery with 66W Fast Charging
#
#                                                 display  \
# 193   6.9 inches, 1400 x 3200 px, 120 Hz Display wit...
# 104   6.43 inches, 1080 x 2400 px Display with Punch...
# 1010  6.5 inches, 720 x 1600 px Display with Water D...
# 806   6.73 inches, 1080 x 2400 px, 144 Hz Display wi...
# 151   6.6 inches, 2460 x 1080 px, 90 Hz Display with...
# 968   6.57 inches, 1080 x 2340 px, 120 Hz Display wi...
#
#                                                  camera  \
# 193              200 MP Penta Rear & 32 MP Front Camera
# 104                48 MP Quad Rear & 16 MP Front Camera
# 1010                      8 MP Rear & 5 MP Front Camera
# 806   50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 151   50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 968               108 MP Quad Rear & 32 MP Front Camera
#
#                                     card             os
# 193                Memory Card Supported  Android v12.1
# 104   Memory Card Supported, upto 256 GB    Android v11
# 1010    Memory Card Supported, upto 1 TB    Android v11
# 806                          Android v13    No FM Radio
# 151                 Memory Card (Hybrid)    Android v12
# 968            Memory Card Not Supported    Android v11

# %% [markdown]
# # **Data Ascessing**
#
#
# > ## **Dirty Data**
#
# * model - some brand names are written differently like POCO/Poco , Oppo/OPPO and other brands. `consistency`
# * price - the price has rupee sign '₹10,00,000' in frunt of the price of the device which is unnecessary. `validity`
# * rating - there some mobile phones that has null values. `completeness`
# * processor - there are some processor that does not have names and there are some that contains error values or you can say garbage values that is not needed. `validity`
# * memory - it contains some error values. `validity`
# * battry - it also has some error values. `validity`
# * display - it contain some error values and missing values. `validity & completeness`
#
# * card - there are some unrequired values and missing values. `validity & completeness`
# * os - some of the values that os feature contains is noisey values, there are some unnecessary special characters available, missing values. `validity & completeness`
# * camera - it contains some missing values. `completeness`
#
# `NOTE : ` There are some noisey values where the values of each columns get interchanged.
#
#
# > ## **Messy Data**
#
# * sim - this contains data about the availability if 5G, doul sim slots and whether it has NFC in one column, there should be diferent columns for each one.
# * ram - this contain the ram and base memory that means that these values should be seperate columns.
# * processor - it can be split into processor name, cores, cpu speed.
# * battery - this also contain how much battry is there and whether the fast charging is available or not.
#
# * display - this contain the size of the display, refresh rate of the display and even the quality of the display and this data should be in seperate columns.
# * camera - the values should be seperate in different columns.
# * card - it can be split into supported or not and how much is supported.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      1020 non-null   object
#  1   price      1020 non-null   object
#  2   rating     879 non-null    float64
#  3   sim        1020 non-null   object
#  4   processor  1020 non-null   object
#  5   ram        1020 non-null   object
#  6   battery    1020 non-null   object
#  7   display    1020 non-null   object
#  8   camera     1019 non-null   object
#  9   card       1013 non-null   object
#  10  os         1003 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 87.8+ KB

# %%
data.describe()
# Out:
#            rating
# count  879.000000
# mean    78.258248
# std      7.402854
# min     60.000000
# 25%     74.000000
# 50%     80.000000
# 75%     84.000000
# max     89.000000

# %%
data['processor'].str.split().str.get(0).value_counts()
# Out:
# processor
# Snapdragon    411
# Helio         200
# Dimensity     177
# Exynos         49
# Bionic         39
# Unisoc         27
# Tiger          24
# Octa           14
# No             13
# Google          9
# Kirin           7
# Quad            6
# Qualcomm        5
# A13             5
# Spreadtrum      4
# 1               3
# 4               3
# SC9863A,        2
# Helio,          2
# 32              2
# 1.77            2
# 52              1
# 48              1
# 256             1
# Single          1
# Samsung         1
# (28             1
# SC6531E,        1
# Dual            1
# 2000            1
# 800             1
# 1450            1
# Fusion          1
# Sanpdragon      1
# Unisoc,         1
# Apple           1
# 8               1
# Name: count, dtype: int64

# %%
df = data.copy()

# %%
df.sample(5)
# Out:
#                                model      price  rating  \
# 171  Xiaomi Redmi Note 13 Pro Max 5G    ₹20,499    83.0
# 394                     Oukitel WP19    ₹29,990    84.0
# 652                    Realme X7 Max    ₹26,999    84.0
# 431            Vertu Signature Touch  ₹6,50,000    62.0
# 242            Samsung Galaxy A75 5G    ₹44,999    83.0
#
#                                                 sim  \
# 171  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 394             Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 652         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 431                  Single Sim, 3G, 4G, Wi-Fi, NFC
# 242         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                              processor  \
# 171  Snapdragon  7 Gen1, Octa Core, 2.36 GHz Processor
# 394              Helio G95, Octa Core, 2 GHz Processor
# 652         Dimensity 1200, Octa Core, 3 GHz Processor
# 431       Snapdragon 801, Octa Core, 1.5 GHz Processor
# 242              Snapdragon 778G+, Octa Core Processor
#
#                           ram                                   battery  \
# 171  6 GB RAM, 128 GB inbuilt   5200 mAh Battery with 67W Fast Charging
# 394  8 GB RAM, 256 GB inbuilt  21000 mAh Battery with 33W Fast Charging
# 652  8 GB RAM, 128 GB inbuilt   4500 mAh Battery with 50W Fast Charging
# 431   2 GB RAM, 64 GB inbuilt                          2275 mAh Battery
# 242  8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 67W Fast Charging
#
#                                                display  \
# 171  6.67 inches, 1080 x 2460 px, 120 Hz Display wi...
# 394  6.78 inches, 1080 x 2400 px Display with Punch...
# 652  6.43 inches, 1080 x 2400 px, 120 Hz Display wi...
# 431                 4.7 inches, 1080 x 1920 px Display
# 242  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                                 camera  \
# 171              108 MP Quad Rear & 32 MP Front Camera
# 394  64 MP + 20 MP + 2 MP Triple Rear & 16 MP Front...
# 652  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 431                   13 MP Rear & 2.1 MP Front Camera
# 242              108 MP Quad Rear & 32 MP Front Camera
#
#                                    card                       os
# 171  Memory Card Supported, upto 512 GB              Android v12
# 394               Memory Card Supported              Android v12
# 652                         Android v11              No FM Radio
# 431           Memory Card Not Supported  Android v4.4.2 (KitKat)
# 242     Memory Card (Hybrid), upto 1 TB              Android v12

# %%
# price

df['price'] = df['price'].str.split('₹').str.get(1).str.replace(',','').astype('int')

# %%
df = df.reset_index()

# %%
df['index'] = df['index'] + 2

# %%
df.head()
# Out:
#    index                      model  price  rating  \
# 0      2              OnePlus 11 5G  54999    89.0
# 1      3  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4      Samsung Galaxy A14 5G  16499    75.0
# 3      5       Motorola Moto G62 5G  14999    81.0
# 4      6         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %%
processor_rows = set((642,647,649,659,667,701,750,759,819,859,883,884,919,927,929,932,1002))
ram_rows = set((441,485,534,553,584,610,613,642,647,649,659,667,701,750,759,819,859,884,919,927,929,932,990,1002))
battery_rows = set((113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,756,759,764,819,855,859,884,915,916,927,929,932,990,1002))
display_rows = set((378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,759,764,819,859,884,915,916,927,929,932,990,1002))
camera_rows = set((100,113,151,157,161,238,273,308,309,323,324,365,367,378,394,441,450,484,506,534,553,571,572,575,584,610,613,615,630,642,647,649,659,667,684,687,705,711,723,728,750,756,759,764,792,819,846,854,855,858,883,884,896,915,916,927,929,932,945,956,990,995,1002,1016 ))

# %%
df[df['index'] == 642]
# Out:
#      index           model  price  rating       sim               processor  \
# 640    642  Nokia 105 Plus   1299     NaN  Dual Sim  4 MB RAM, 4 MB inbuilt
#
#                  ram                            battery         display  \
# 640  800 mAh Battery  1.77 inches, 128 x 160 px Display  No Rear Camera
#
#                                 camera       card   os
# 640  Memory Card Supported, upto 32 GB  Bluetooth  NaN

# %%
df[df['index'].isin(processor_rows | ram_rows | battery_rows | display_rows | camera_rows)]
# Out:
#       index                              model   price  rating  \
# 98      100                     Vivo X Fold 5G  106990     NaN
# 111     113                    Apple iPhone 12   51999    74.0
# 149     151               Apple iPhone 12 Mini   40999    74.0
# 155     157                    Nokia 2780 Flip    4990     NaN
# 159     161                    Oppo Find N2 5G   94990     NaN
# ...     ...                                ...     ...     ...
# 954     956  Vivo X Fold 5G (12GB RAM + 512GB)  118990     NaN
# 988     990                Nokia 5310 Dual Sim    3399     NaN
# 993     995                      Huawei Mate X  169000     NaN
# 1000   1002                    XTouch F40 Flip    1999     NaN
# 1014   1016                      Vivo X Fold 2  119990     NaN
#
#                                                     sim  \
# 98              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 111             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 155                             Dual Sim, 3G, 4G, Wi-Fi
# 159             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...                                                 ...
# 954             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 988                                            Dual Sim
# 993   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1000                                           Dual Sim
# 1014            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                              processor  \
# 98       Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 111           Bionic A14, Hexa Core, 3.1 GHz Processor
# 149           Bionic A14, Hexa Core, 3.1 GHz Processor
# 155     Snapdragon QM215, Quad Core, 1.3 GHz Processor
# 159   Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# ...                                                ...
# 954      Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 988                            8 MB RAM, 16 MB inbuilt
# 993          Kirin  990, Octa Core, 2.86 GHz Processor
# 1000                                             No 3G
# 1014   Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
#
#                             ram  \
# 98    12 GB RAM, 256 GB inbuilt
# 111     4 GB RAM, 64 GB inbuilt
# 149     4 GB RAM, 64 GB inbuilt
# 155    4 GB RAM, 512 MB inbuilt
# 159   12 GB RAM, 256 GB inbuilt
# ...                         ...
# 954   12 GB RAM, 512 GB inbuilt
# 988            1200 mAh Battery
# 993    8 GB RAM, 512 GB inbuilt
# 1000                    No Wifi
# 1014  12 GB RAM, 256 GB inbuilt
#
#                                                 battery  \
# 98              4600 mAh Battery with 66W Fast Charging
# 111   6.1 inches, 1170 x 2532 px Display with Large ...
# 149                  5.4 inches, 1080 x 2340 px Display
# 155                                    1450 mAh Battery
# 159             4520 mAh Battery with 67W Fast Charging
# ...                                                 ...
# 954             4600 mAh Battery with 66W Fast Charging
# 988                    2.4 inches, 240 x 320 px Display
# 993             4500 mAh Battery with 55W Fast Charging
# 1000                           32 MB RAM, 32 MB inbuilt
# 1014            4800 mAh Battery with 66W Fast Charging
#
#                                                 display  \
# 98          8.03 inches, 1916 x 2160 px, 120 Hz Display
# 111        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 149        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 155                    2.7 inches, 240 x 320 px Display
# 159   7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# ...                                                 ...
# 954         8.03 inches, 1916 x 2160 px, 120 Hz Display
# 988                                  0.3 MP Rear Camera
# 993                    8 inches, 2200 x 2480 px Display
# 1000                                    800 mAh Battery
# 1014        8.03 inches, 1916 x 2160 px, 120 Hz Display
#
#                                  camera  \
# 98                     Foldable Display
# 111           Memory Card Not Supported
# 149           Memory Card Not Supported
# 155                        Dual Display
# 159      Foldable Display, Dual Display
# ...                                 ...
# 954                    Foldable Display
# 988   Memory Card Supported, upto 32 GB
# 993                    Foldable Display
# 1000  1.77 inches, 240 x 320 px Display
# 1014                   Foldable Display
#
#                                                    card  \
# 98                 50 MP Quad Rear & 16 MP Front Camera
# 111                                             iOS v14
# 149                                             iOS v14
# 155                                    5 MP Rear Camera
# 159   50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...
# ...                                                 ...
# 954                50 MP Quad Rear & 16 MP Front Camera
# 988                                           Bluetooth
# 993                              48 MP Quad Rear Camera
# 1000                                       Dual Display
# 1014  50 MP + 50 MP + 10 MP Triple Rear & 32 MP Fron...
#
#                                      os
# 98                          Android v12
# 111                         No FM Radio
# 149                         No FM Radio
# 155   Memory Card Supported, upto 32 GB
# 159           Memory Card Not Supported
# ...                                 ...
# 954                         Android v12
# 988                             Browser
# 993   Memory Card (Hybrid), upto 256 GB
# 1000                 1.3 MP Rear Camera
# 1014                        Android v12
#
# [68 rows x 12 columns]

# %%
df[df['index'].isin(processor_rows & ram_rows & battery_rows & display_rows & camera_rows)]
# Out:
#       index                   model  price  rating  \
# 640     642          Nokia 105 Plus   1299     NaN
# 645     647         Nokia 2760 Flip   5490     NaN
# 647     649       Motorola Moto A10   1339     NaN
# 657     659           Zanco Tiny T1   2799     NaN
# 665     667            itel it2163S    958     NaN
# 748     750            Nokia 400 4G   3290     NaN
# 757     759            Karbonn KU3i    995     NaN
# 817     819            itel Magic X   2239     NaN
# 882     884  Nokia 5710 XpressAudio   4799     NaN
# 925     927           Nokia 3310 4G   3999     NaN
# 927     929      Samsung Guru E1200   1685     NaN
# 930     932        iKall K88 Pro 4G   2099     NaN
# 1000   1002         XTouch F40 Flip   1999     NaN
#
#                                  sim                   processor  \
# 640                         Dual Sim      4 MB RAM, 4 MB inbuilt
# 645          Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# 647                         Dual Sim      4 MB RAM, 4 MB inbuilt
# 657                       Single Sim    32 MB RAM, 32 MB inbuilt
# 665                         Dual Sim      4 MB RAM, 4 MB inbuilt
# 748       Dual Sim, 4G, VoLTE, Wi-Fi            2000 mAh Battery
# 757                         Dual Sim    52 MB RAM, 32 MB inbuilt
# 817   Dual Sim, 3G, 4G, VoLTE, Wi-Fi                       No 3G
# 882                 Dual Sim, 3G, 4G                     No Wifi
# 925   Dual Sim, 3G, 4G, VoLTE, Wi-Fi  256 MB RAM, 512 MB inbuilt
# 927                       Single Sim                     No Wifi
# 930          Dual Sim, 3G, 4G, VoLTE   48 MB RAM, 128 MB inbuilt
# 1000                        Dual Sim                       No 3G
#
#                                    ram                            battery  \
# 640                    800 mAh Battery  1.77 inches, 128 x 160 px Display
# 645   3.6 inches, 240 x 320 px Display      5 MP Rear & 5 MP Front Camera
# 647                   1750 mAh Battery   1.8 inches, 160 x 128 px Display
# 657                    200 mAh Battery    0.49 inches, 64 x 32 px Display
# 665                   1200 mAh Battery   1.8 inches, 160 x 128 px Display
# 748   2.4 inches, 240 x 320 px Display  0.3 MP Rear & 0.3 MP Front Camera
# 757                   1000 mAh Battery   1.8 inches, 128 x 160 px Display
# 817                               T117          48 MB RAM, 128 MB inbuilt
# 882                        Unisoc T107          48 MB RAM, 128 MB inbuilt
# 925                   1200 mAh Battery   2.4 inches, 240 x 320 px Display
# 927                    800 mAh Battery   1.5 inches, 128 x 128 px Display
# 930                   1800 mAh Battery   2.4 inches, 240 x 360 px Display
# 1000                           No Wifi           32 MB RAM, 32 MB inbuilt
#
#                                 display                              camera  \
# 640                      No Rear Camera   Memory Card Supported, upto 32 GB
# 645   Memory Card Supported, upto 32 GB                          Kaios v3.0
# 647                      No Rear Camera   Memory Card Supported, upto 32 GB
# 657                      No Rear Camera                         No FM Radio
# 665                      No Rear Camera   Memory Card Supported, upto 32 GB
# 748   Memory Card Supported, upto 64 GB                           Bluetooth
# 757                      No Rear Camera   Memory Card Supported, upto 16 GB
# 817                    1200 mAh Battery    2.4 inches, 240 x 320 px Display
# 882                    1450 mAh Battery    2.4 inches, 240 x 320 px Display
# 925                    2 MP Rear Camera   Memory Card Supported, upto 32 GB
# 927                      No Rear Camera                         No FM Radio
# 930                  0.3 MP Rear Camera  Memory Card Supported, upto 128 GB
# 1000                    800 mAh Battery   1.77 inches, 240 x 320 px Display
#
#                     card                                 os
# 640            Bluetooth                                NaN
# 645            Bluetooth                                NaN
# 647                  NaN                                NaN
# 657            Bluetooth                                NaN
# 665            Bluetooth                                NaN
# 748              Browser                                NaN
# 757            Bluetooth                                NaN
# 817   1.3 MP Rear Camera  Memory Card Supported, upto 64 GB
# 882   0.3 MP Rear Camera  Memory Card Supported, upto 32 GB
# 925            Bluetooth                            Browser
# 927                  NaN                                NaN
# 930            Bluetooth                            Browser
# 1000        Dual Display                 1.3 MP Rear Camera

# %%
df = df[df['price'] > 3400]

# %%
df[df['index'].isin(processor_rows)]
# Out:
#      index                   model  price  rating  \
# 645    647         Nokia 2760 Flip   5490     NaN
# 857    859             LG Folder 2  11999     NaN
# 882    884  Nokia 5710 XpressAudio   4799     NaN
# 925    927           Nokia 3310 4G   3999     NaN
#
#                                 sim                   processor  \
# 645         Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# 857       Single Sim, 3G, 4G, Wi-Fi      1 GB RAM, 8 GB inbuilt
# 882                Dual Sim, 3G, 4G                     No Wifi
# 925  Dual Sim, 3G, 4G, VoLTE, Wi-Fi  256 MB RAM, 512 MB inbuilt
#
#                                   ram                           battery  \
# 645  3.6 inches, 240 x 320 px Display     5 MP Rear & 5 MP Front Camera
# 857                  1470 mAh Battery  2.8 inches, 240 x 320 px Display
# 882                       Unisoc T107         48 MB RAM, 128 MB inbuilt
# 925                  1200 mAh Battery  2.4 inches, 240 x 320 px Display
#
#                                display                             camera  \
# 645  Memory Card Supported, upto 32 GB                         Kaios v3.0
# 857                   2 MP Rear Camera              Memory Card Supported
# 882                   1450 mAh Battery   2.4 inches, 240 x 320 px Display
# 925                   2 MP Rear Camera  Memory Card Supported, upto 32 GB
#
#                    card                                 os
# 645           Bluetooth                                NaN
# 857           Bluetooth                                NaN
# 882  0.3 MP Rear Camera  Memory Card Supported, upto 32 GB
# 925           Bluetooth                            Browser

# %%
df.drop([645,857,882,925], inplace=True)

# %%
df[df['index'].isin(ram_rows)]
# Out:
#      index                             model   price  rating  \
# 439    441            Apple iPhone SE 3 2022   43900     NaN
# 483    485  Huawei Mate 50 RS Porsche Design  239999    81.0
# 582    584                     Nokia 8210 4G    3749     NaN
#
#                                                  sim  \
# 439          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 582                                 Dual Sim, 3G, 4G
#
#                                             processor             ram  \
# 439        Bionic  A15, Hexa Core, 3.22 GHz Processor   64 GB inbuilt
# 483  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  512 GB inbuilt
# 582                                           No Wifi     Unisoc T107
#
#                                      battery  \
# 439        4.7 inches, 750 x 1334 px Display
# 483  4700 mAh Battery with 66W Fast Charging
# 582                48 MB RAM, 128 MB inbuilt
#
#                                          display  \
# 439               12 MP Rear & 7 MP Front Camera
# 483  6.74 inches, 1212 x 2616 px, 120 Hz Display
# 582                             1450 mAh Battery
#
#                                                 camera  \
# 439                          Memory Card Not Supported
# 483  50 MP + 48 MP + 13 MP Triple Rear & 13 MP Fron...
# 582                   2.8 inches, 240 x 320 px Display
#
#                                   card                                 os
# 439                            iOS v15                        No FM Radio
# 483  Memory Card (Hybrid), upto 256 GB                   Hongmeng OS v3.0
# 582                 0.3 MP Rear Camera  Memory Card Supported, upto 32 GB

# %%
df.drop(582, inplace=True)

# %%
df[df['index'].isin(battery_rows)]
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 307    309       Apple iPhone 12 (128GB)   55999    75.0
# 363    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 376    378               Nokia 2660 Flip    4649     NaN
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 754    756    Apple iPod Touch (7th Gen)   18900     NaN
# 762    764             Apple iPhone SE 4   49990    60.0
# 853    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 363  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 376                         Dual Sim, 3G, 4G
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 448  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 628  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 754                                    Wi-Fi
# 762  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 853  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 913  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 914  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                       processor  \
# 111    Bionic A14, Hexa Core, 3.1 GHz Processor
# 149    Bionic A14, Hexa Core, 3.1 GHz Processor
# 307    Bionic A14, Hexa Core, 3.1 GHz Processor
# 363    Bionic A14, Hexa Core, 3.1 GHz Processor
# 376                                     No Wifi
# 439  Bionic  A15, Hexa Core, 3.22 GHz Processor
# 448                                 Bionic  A16
# 628    Bionic A14, Hexa Core, 3.1 GHz Processor
# 754                               32 GB inbuilt
# 762  Bionic  A15, Hexa Core, 3.22 GHz Processor
# 853    Bionic A14, Hexa Core, 3.1 GHz Processor
# 913    Bionic A14, Hexa Core, 3.1 GHz Processor
# 914    Bionic A14, Hexa Core, 3.1 GHz Processor
#
#                                  ram  \
# 111          4 GB RAM, 64 GB inbuilt
# 149          4 GB RAM, 64 GB inbuilt
# 307         4 GB RAM, 128 GB inbuilt
# 363         4 GB RAM, 128 GB inbuilt
# 376                      Unisoc T107
# 439                    64 GB inbuilt
# 448         8 GB RAM, 128 GB inbuilt
# 628         6 GB RAM, 512 GB inbuilt
# 754  4 inches, 640 x 1136 px Display
# 762                    64 GB inbuilt
# 853         6 GB RAM, 256 GB inbuilt
# 913         4 GB RAM, 256 GB inbuilt
# 914         4 GB RAM, 256 GB inbuilt
#
#                                                battery  \
# 111  6.1 inches, 1170 x 2532 px Display with Large ...
# 149                 5.4 inches, 1080 x 2340 px Display
# 307  6.1 inches, 1170 x 2532 px Display with Large ...
# 363                 5.4 inches, 1080 x 2340 px Display
# 376                          48 MB RAM, 128 MB inbuilt
# 439                  4.7 inches, 750 x 1334 px Display
# 448  6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 628  6.1 inches, 1170 x 2532 px Display with Large ...
# 754                    8 MP Rear & 1.2 MP Front Camera
# 762                  6.1 inches, 750 x 1580 px Display
# 853  6.1 inches, 1170 x 2532 px Display with Large ...
# 913                 5.4 inches, 1080 x 2340 px Display
# 914  6.1 inches, 1170 x 2532 px Display with Large ...
#
#                                                display  \
# 111       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 149       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 307       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 363       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 376                                   1450 mAh Battery
# 439                     12 MP Rear & 7 MP Front Camera
# 448  50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 628  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 754                                            iOS v12
# 762                  12 MP Rear & 10.8 MP Front Camera
# 853  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 913       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 914       12 MP + 12 MP Dual Rear & 12 MP Front Camera
#
#                                camera          card                  os
# 111         Memory Card Not Supported       iOS v14         No FM Radio
# 149         Memory Card Not Supported       iOS v14         No FM Radio
# 307         Memory Card Not Supported       iOS v14         No FM Radio
# 363         Memory Card Not Supported       iOS v14         No FM Radio
# 376  2.8 inches, 240 x 320 px Display  Dual Display  0.3 MP Rear Camera
# 439         Memory Card Not Supported       iOS v15         No FM Radio
# 448         Memory Card Not Supported       iOS v15         No FM Radio
# 628         Memory Card Not Supported     iOS v14.0         No FM Radio
# 754                       No FM Radio     Bluetooth             Browser
# 762         Memory Card Not Supported       iOS v16         No FM Radio
# 853         Memory Card Not Supported     iOS v14.0         No FM Radio
# 913         Memory Card Not Supported       iOS v14         No FM Radio
# 914         Memory Card Not Supported       iOS v14         No FM Radio

# %%
df.drop([376, 754], inplace=True)

# %%
temp_df = df[df['index'].isin(battery_rows)]

# %%
x = temp_df.iloc[:,7:].shift(1,axis=1).values

# %%
df.loc[temp_df.index,temp_df.columns[7:]] = x

# %%
df[df['index'].isin(battery_rows)]
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 307    309       Apple iPhone 12 (128GB)   55999    75.0
# 363    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 762    764             Apple iPhone SE 4   49990    60.0
# 853    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 363  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 448  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 628  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 762  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 853  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 913  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 914  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                       processor                       ram  \
# 111    Bionic A14, Hexa Core, 3.1 GHz Processor   4 GB RAM, 64 GB inbuilt
# 149    Bionic A14, Hexa Core, 3.1 GHz Processor   4 GB RAM, 64 GB inbuilt
# 307    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 128 GB inbuilt
# 363    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 128 GB inbuilt
# 439  Bionic  A15, Hexa Core, 3.22 GHz Processor             64 GB inbuilt
# 448                                 Bionic  A16  8 GB RAM, 128 GB inbuilt
# 628    Bionic A14, Hexa Core, 3.1 GHz Processor  6 GB RAM, 512 GB inbuilt
# 762  Bionic  A15, Hexa Core, 3.22 GHz Processor             64 GB inbuilt
# 853    Bionic A14, Hexa Core, 3.1 GHz Processor  6 GB RAM, 256 GB inbuilt
# 913    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 256 GB inbuilt
# 914    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 256 GB inbuilt
#
#     battery                                            display  \
# 111    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 149    None                 5.4 inches, 1080 x 2340 px Display
# 307    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 363    None                 5.4 inches, 1080 x 2340 px Display
# 439    None                  4.7 inches, 750 x 1334 px Display
# 448    None  6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 628    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 762    None                  6.1 inches, 750 x 1580 px Display
# 853    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 913    None                 5.4 inches, 1080 x 2340 px Display
# 914    None  6.1 inches, 1170 x 2532 px Display with Large ...
#
#                                                 camera  \
# 111       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 149       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 307       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 363       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 439                     12 MP Rear & 7 MP Front Camera
# 448  50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 628  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 762                  12 MP Rear & 10.8 MP Front Camera
# 853  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 913       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 914       12 MP + 12 MP Dual Rear & 12 MP Front Camera
#
#                           card         os
# 111  Memory Card Not Supported    iOS v14
# 149  Memory Card Not Supported    iOS v14
# 307  Memory Card Not Supported    iOS v14
# 363  Memory Card Not Supported    iOS v14
# 439  Memory Card Not Supported    iOS v15
# 448  Memory Card Not Supported    iOS v15
# 628  Memory Card Not Supported  iOS v14.0
# 762  Memory Card Not Supported    iOS v16
# 853  Memory Card Not Supported  iOS v14.0
# 913  Memory Card Not Supported    iOS v14
# 914  Memory Card Not Supported    iOS v14

# %%
df[df['index'].isin(display_rows)]
# Out:
#      index                         model   price  rating  \
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 762    764             Apple iPhone SE 4   49990    60.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 448  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 628  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 762  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 913  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 914  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                       processor                       ram  \
# 439  Bionic  A15, Hexa Core, 3.22 GHz Processor             64 GB inbuilt
# 448                                 Bionic  A16  8 GB RAM, 128 GB inbuilt
# 628    Bionic A14, Hexa Core, 3.1 GHz Processor  6 GB RAM, 512 GB inbuilt
# 762  Bionic  A15, Hexa Core, 3.22 GHz Processor             64 GB inbuilt
# 913    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 256 GB inbuilt
# 914    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 256 GB inbuilt
#
#     battery                                            display  \
# 439    None                  4.7 inches, 750 x 1334 px Display
# 448    None  6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 628    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 762    None                  6.1 inches, 750 x 1580 px Display
# 913    None                 5.4 inches, 1080 x 2340 px Display
# 914    None  6.1 inches, 1170 x 2532 px Display with Large ...
#
#                                                 camera  \
# 439                     12 MP Rear & 7 MP Front Camera
# 448  50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 628  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 762                  12 MP Rear & 10.8 MP Front Camera
# 913       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 914       12 MP + 12 MP Dual Rear & 12 MP Front Camera
#
#                           card         os
# 439  Memory Card Not Supported    iOS v15
# 448  Memory Card Not Supported    iOS v15
# 628  Memory Card Not Supported  iOS v14.0
# 762  Memory Card Not Supported    iOS v16
# 913  Memory Card Not Supported    iOS v14
# 914  Memory Card Not Supported    iOS v14

# %%
len(display_rows)
# Out:
# 27

# %%
df[df['index'].isin(camera_rows)].head()
# Out:
#      index                 model   price  rating  \
# 98     100        Vivo X Fold 5G  106990     NaN
# 111    113       Apple iPhone 12   51999    74.0
# 149    151  Apple iPhone 12 Mini   40999    74.0
# 155    157       Nokia 2780 Flip    4990     NaN
# 159    161       Oppo Find N2 5G   94990     NaN
#
#                                          sim  \
# 98   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 155                  Dual Sim, 3G, 4G, Wi-Fi
# 159  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                             processor  \
# 98      Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 111          Bionic A14, Hexa Core, 3.1 GHz Processor
# 149          Bionic A14, Hexa Core, 3.1 GHz Processor
# 155    Snapdragon QM215, Quad Core, 1.3 GHz Processor
# 159  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
#
#                            ram                                  battery  \
# 98   12 GB RAM, 256 GB inbuilt  4600 mAh Battery with 66W Fast Charging
# 111    4 GB RAM, 64 GB inbuilt                                     None
# 149    4 GB RAM, 64 GB inbuilt                                     None
# 155   4 GB RAM, 512 MB inbuilt                         1450 mAh Battery
# 159  12 GB RAM, 256 GB inbuilt  4520 mAh Battery with 67W Fast Charging
#
#                                                display  \
# 98         8.03 inches, 1916 x 2160 px, 120 Hz Display
# 111  6.1 inches, 1170 x 2532 px Display with Large ...
# 149                 5.4 inches, 1080 x 2340 px Display
# 155                   2.7 inches, 240 x 320 px Display
# 159  7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
#
#                                            camera  \
# 98                               Foldable Display
# 111  12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 149  12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 155                                  Dual Display
# 159                Foldable Display, Dual Display
#
#                                                   card  \
# 98                50 MP Quad Rear & 16 MP Front Camera
# 111                          Memory Card Not Supported
# 149                          Memory Card Not Supported
# 155                                   5 MP Rear Camera
# 159  50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...
#
#                                     os
# 98                         Android v12
# 111                            iOS v14
# 149                            iOS v14
# 155  Memory Card Supported, upto 32 GB
# 159          Memory Card Not Supported

# %%
df.drop([155,271],inplace=True)

# %%
temp_df = df[df['index'].isin(camera_rows)]

# %%
temp_df = temp_df[~temp_df['camera'].str.contains('MP')]

# %%
df.loc[temp_df.index, 'camera'] = temp_df['card'].values

# %%
print(df['card'].value_counts())
# Out:
# card
# Memory Card Supported, upto 1 TB                                       171
# Memory Card Not Supported                                              123
# Android v12                                                            107
# Memory Card Supported, upto 512 GB                                     105
# Memory Card (Hybrid), upto 1 TB                                         91
# Memory Card Supported                                                   89
# Memory Card Supported, upto 256 GB                                      87
# Android v13                                                             46
# Android v11                                                             41
# Memory Card (Hybrid)                                                    30
# Memory Card (Hybrid), upto 256 GB                                       13
# Android v10                                                             11
# Memory Card (Hybrid), upto 512 GB                                       11
# Memory Card Supported, upto 128 GB                                       6
# Memory Card Supported, upto 2 TB                                         5
# Memory Card Supported, upto 32 GB                                        4
# Memory Card (Hybrid), upto 64 GB                                         3
# Memory Card (Hybrid), upto 128 GB                                        3
# Android v9.0 (Pie)                                                       2
# 50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 MP Dual Front Camera       2
# 64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front Camera                    2
# 50 MP + 8 MP Dual Rear & 32 MP Front Camera                              2
# 12 MP + 12 MP Dual Rear & 10 MP Front Camera                             2
# 50 MP Quad Rear & 16 MP Front Camera                                     2
# 64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Front Camera                  1
# 48 MP Quad Rear Camera                                                   1
# HarmonyOS                                                                1
# Memory Card (Hybrid), upto 2 TB                                          1
# 5 MP Rear & 2 MP Front Camera                                            1
# 108 MP + 13 MP + 8 MP Triple Rear & 20 MP Front Camera                   1
# HarmonyOS v2.0                                                           1
# 50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Front Camera                  1
# 50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front Camera                    1
# 64 MP + 16 MP + 12 MP Triple Rear & 16 MP Front Camera                   1
# 50 MP + 16 MP + 13 MP Triple Rear & 32 MP Front Camera                   1
# iOS v13                                                                  1
# 50 MP + 13 MP + 8 MP Triple Rear & 20 MP Front Camera                    1
# Android v10.0                                                            1
# 64 MP + 20 MP + 2 MP Triple Rear & Main Front Camera                     1
# iOS v10                                                                  1
# 64 MP + 13 MP + 12 MP Triple Rear & 32 MP Front Camera                   1
# 12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 MP Dual Front Camera       1
# Memory Card Supported, upto 1000 GB                                      1
# 50 MP Quad Rear & 16 MP + 16 MP Dual Front Camera                        1
# 64 MP + 10 MP + 8 MP Triple Rear & 32 MP Front Camera                    1
# Android v12.1                                                            1
# 50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32 MP Dual Front Camera      1
# 50 MP + 50 MP + 10 MP Triple Rear & 32 MP Front Camera                   1
# Name: count, dtype: int64

# %%
temp_df = df[df['card'].str.contains('MP')]

# %%
df.loc[temp_df.index, 'card'] = 'Memory Card Not Supported'

# %%
print(df['card'].value_counts())
# Out:
# card
# Memory Card Supported, upto 1 TB       171
# Memory Card Not Supported              149
# Android v12                            107
# Memory Card Supported, upto 512 GB     105
# Memory Card (Hybrid), upto 1 TB         91
# Memory Card Supported                   89
# Memory Card Supported, upto 256 GB      87
# Android v13                             46
# Android v11                             41
# Memory Card (Hybrid)                    30
# Memory Card (Hybrid), upto 256 GB       13
# Memory Card (Hybrid), upto 512 GB       11
# Android v10                             11
# Memory Card Supported, upto 128 GB       6
# Memory Card Supported, upto 2 TB         5
# Memory Card Supported, upto 32 GB        4
# Memory Card (Hybrid), upto 64 GB         3
# Memory Card (Hybrid), upto 128 GB        3
# Android v9.0 (Pie)                       2
# Android v12.1                            1
# Memory Card Supported, upto 1000 GB      1
# iOS v10                                  1
# Android v10.0                            1
# iOS v13                                  1
# HarmonyOS v2.0                           1
# Memory Card (Hybrid), upto 2 TB          1
# HarmonyOS                                1
# Name: count, dtype: int64

# %%
pd.set_option('display.max_rows', None)

# %%
temp_df = df[~df['card'].str.contains('Memory Card')]

# %%
df.loc[temp_df.index, 'card'] = 'Memory Card Not Supported'

# %%
print(df['card'].value_counts())
# Out:
# card
# Memory Card Not Supported              362
# Memory Card Supported, upto 1 TB       171
# Memory Card Supported, upto 512 GB     105
# Memory Card (Hybrid), upto 1 TB         91
# Memory Card Supported                   89
# Memory Card Supported, upto 256 GB      87
# Memory Card (Hybrid)                    30
# Memory Card (Hybrid), upto 256 GB       13
# Memory Card (Hybrid), upto 512 GB       11
# Memory Card Supported, upto 128 GB       6
# Memory Card Supported, upto 2 TB         5
# Memory Card Supported, upto 32 GB        4
# Memory Card (Hybrid), upto 128 GB        3
# Memory Card (Hybrid), upto 64 GB         3
# Memory Card Supported, upto 1000 GB      1
# Memory Card (Hybrid), upto 2 TB          1
# Name: count, dtype: int64

# %%
df.loc[temp_df.index, 'os'] = temp_df['card'].values

# %%
print(df['os'].value_counts())
# Out:
# os
# Android v12                           394
# Android v11                           274
# Android v13                            91
# Android v10                            69
# Android v9.0 (Pie)                     29
# Android v10.0                          23
# iOS v16                                15
# iOS v15                                12
# Android v8.1 (Oreo)                    10
# iOS v14                                 6
# Memory Card Not Supported               6
# Android v11.0                           4
# Android v8.0 (Oreo)                     4
# iOS v13                                 4
# iOS v15.0                               3
# Android v6.0 (Marshmallow)              2
# Memory Card (Hybrid), upto 256 GB       2
# Memory Card (Hybrid), upto 2 TB         2
# HarmonyOS v2.0                          2
# Android v5.1.1 (Lollipop)               2
# Harmony v2.0                            2
# EMUI v12                                2
# Memory Card Supported, upto 256 GB      2
# Android v12.1                           2
# iOS v14.0                               2
# Memory Card Supported, upto 128 GB      1
# Android v7.1 (Nougat)                   1
# Android                                 1
# Hongmeng OS v4.0                        1
# HarmonyOS                               1
# Android v5.1 (Lollipop)                 1
# RTOS (Series 30+)                       1
# Memory Card (Hybrid)                    1
# iOS v10                                 1
# Pragati OS (Powered by Android)         1
# Bluetooth                               1
# Hongmeng OS v3.0                        1
# Android v4.4.2 (KitKat)                 1
# iOS v17                                 1
# iOS v12.3                               1
# iOS v13.0                               1
# HarmonyOS v2                            1
# Android v9 (Pie)                        1
# Name: count, dtype: int64

# %%
temp_df = df[df['os'] == 'Bluetooth']

# %%
df.loc[temp_df.index,'os'] = np.nan

# %%
df.sample(5)
# Out:
#      index                              model  price  rating  \
# 410    412                   Asus ROG Phone 7  75990    87.0
# 678    680       Xiaomi Redmi Note 10 Pro Max  19999    81.0
# 806    808                   Realme GT Neo 4T  29999    80.0
# 735    737                     Tecno Pop 5 Go   6999     NaN
# 824    826  Infinix Note 12 (6GB RAM + 128GB)  12999    77.0
#
#                                             sim  \
# 410     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 678  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster
# 806    Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi
# 735                         Dual Sim, 3G, Wi-Fi
# 824              Dual Sim, 3G, 4G, VoLTE, Wi-Fi
#
#                                             processor  \
# 410   Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 678    Snapdragon  732G, Octa Core, 2.3 GHz Processor
# 806     Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 735  Spreadtrum  SC7731, Quad Core, 1.3 GHz Processor
# 824             Helio G88, Octa Core, 2 GHz Processor
#
#                            ram                                   battery  \
# 410  18 GB RAM, 256 GB inbuilt  6000 mAh Battery with 120W Fast Charging
# 678    6 GB RAM, 64 GB inbuilt   5020 mAh Battery with 33W Fast Charging
# 806   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 120W Fast Charging
# 735    1 GB RAM, 16 GB inbuilt                          4000 mAh Battery
# 824   6 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
#
#                                                display  \
# 410         6.8 inches, 1080 x 2448 px, 165 Hz Display
# 678  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 806  6.73 inches, 1080 x 2400 px, 144 Hz Display wi...
# 735  6.1 inches, 720 x 1520 px Display with Water D...
# 824  6.7 inches, 2400 x 1080 px Display with Punch ...
#
#                                                 camera  \
# 410  64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 678              108 MP Quad Rear & 16 MP Front Camera
# 806  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 735        5 MP + 0.3 MP Dual Rear & 5 MP Front Camera
# 824      50 MP + 2 MP Triple Rear & 16 MP Front Camera
#
#                                    card           os
# 410           Memory Card Not Supported  Android v13
# 678  Memory Card Supported, upto 512 GB  Android v11
# 806           Memory Card Not Supported  Android v13
# 735               Memory Card Supported  Android v11
# 824  Memory Card Supported, upto 512 GB  Android v11

# %%
print(df['display'].value_counts())
# Out:
# display
# 6.67 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole          54
# 6.5 inches, 720 x 1600 px Display with Water Drop Notch              36
# 6.7 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole           25
# 6.52 inches, 720 x 1600 px Display with Water Drop Notch             23
# 6.5 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole            22
# 6.51 inches, 720 x 1600 px Display with Water Drop Notch             21
# 6.43 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole           19
# 6.43 inches, 1080 x 2400 px Display with Punch Hole                  16
# 6.62 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole          15
# 6.53 inches, 720 x 1600 px Display with Water Drop Notch             14
# 6.4 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole            14
# 6.55 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole          11
# 6.7 inches, 1440 x 3216 px, 120 Hz Display with Punch Hole           10
# 6.58 inches, 1080 x 2408 px, 120 Hz Display with Water Drop Notch    10
# 6.5 inches, 720 x 1600 px, 90 Hz Display with Water Drop Notch       10
# 6.6 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole            10
# 6.7 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole           10
# 6.5 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole           10
# 6.67 inches, 1080 x 2400 px Display with Punch Hole                   9
# 6.6 inches, 1080 x 2408 px Display with Water Drop Notch              9
# 6.55 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole            9
# 6.6 inches, 1080 x 2408 px, 90 Hz Display with Water Drop Notch       9
# 6.78 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole           9
# 6.7 inches, 1080 x 2400 px Display with Punch Hole                    8
# 6.58 inches, 1080 x 2408 px, 90 Hz Display with Water Drop Notch      8
# 6.5 inches, 720 x 1600 px, 90 Hz Display with Punch Hole              7
# 6.59 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole           7
# 6.6 inches, 1080 x 2408 px, 120 Hz Display with Water Drop Notch      7
# 6.53 inches, 1080 x 2340 px Display with Water Drop Notch             7
# 6.6 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole            7
# 6.58 inches, 1080 x 2400 px, 90 Hz Display with Water Drop Notch      7
# 6.58 inches, 1080 x 2408 px Display with Water Drop Notch             7
# 6.67 inches, 1080 x 2400 px, 144 Hz Display with Punch Hole           7
# 6.1 inches, 1170 x 2532 px Display with Small Notch                   6
# 6.73 inches, 1440 x 3200 px, 120 Hz Display with Punch Hole           6
# 6.4 inches, 1080 x 2400 px, 90 Hz Display with Water Drop Notch       6
# 6.44 inches, 1080 x 2400 px Display with Water Drop Notch             6
# 6.1 inches, 1170 x 2532 px Display with Large Notch                   5
# 6.6 inches, 1080 x 2460 px, 144 Hz Display with Punch Hole            5
# 6.5 inches, 720 x 1560 px Display with Water Drop Notch               5
# 6.4 inches, 1080 x 2340 px Display with Water Drop Notch              5
# 6.4 inches, 1080 x 2400 px Display with Punch Hole                    5
# 6.67 inches, 1440 x 3200 px, 120 Hz Display with Punch Hole           5
# 6.8 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole            5
# 6.44 inches, 1080 x 2404 px, 90 Hz Display with Water Drop Notch      5
# 6.56 inches, 720 x 1612 px, 90 Hz Display with Water Drop Notch       5
# 6.67 inches, 1080 x 2460 px, 120 Hz Display with Punch Hole           5
# 6.56 inches, 720 x 1612 px Display with Water Drop Notch              5
# 6.6 inches, 720 x 1612 px, 90 Hz Display with Water Drop Notch        4
# 6.6 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole            4
# 6.7 inches, 720 x 1600 px Display with Water Drop Notch               4
# 6.7 inches, 1290 x 2796 px, 120 Hz Display                            4
# 6.56 inches, 1080 x 2376 px, 120 Hz Display with Punch Hole           4
# 6.67 inches, 2400 x 1080 px, 120 Hz Display with Punch Hole           4
# 6.5 inches, 1600 x 720 px Display with Water Drop Notch               4
# 6.56 inches, 720 x 1600 px Display with Water Drop Notch              4
# 6.7 inches, 1080 x 2400 px Display with Water Drop Notch              4
# 6.35 inches, 720 x 1544 px Display with Water Drop Notch              4
# 6.78 inches, 1440 x 3200 px, 120 Hz Display with Punch Hole           4
# 6.78 inches, 1080 x 2448 px, 165 Hz Display                           4
# 6.2 inches, 720 x 1520 px Display with Water Drop Notch               3
# 6.4 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole            3
# 6.78 inches, 1080 x 2460 px, 120 Hz Display with Punch Hole           3
# 6.6 inches, 2460 x 1080 px, 90 Hz Display with Punch Hole             3
# 6.7 inches, 1284 x 2778 px, 120 Hz Display with Small Notch           3
# 6.73 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole           3
# 6.1 inches, 1170 x 2532 px, 120 Hz Display with Large Notch           3
# 4.7 inches, 750 x 1334 px Display                                     3
# 5 inches, 854 x 480 px Display                                        3
# 6.8 inches, 1080 x 2460 px Display with Punch Hole                    3
# 6.44 inches, 1080 x 2408 px, 90 Hz Display with Water Drop Notch      3
# 6.6 inches, 720 x 1600 px Display with Water Drop Notch               3
# 6.8 inches, 1116 x 2480 px, 120 Hz Display                            3
# 6.8 inches, 1080 x 2460 px, 120 Hz Display with Punch Hole            3
# 6.7 inches, 2400 x 1080 px Display with Punch Hole                    3
# 6.6 inches, 720 x 1600 px, 90 Hz Display with Water Drop Notch        3
# 5.4 inches, 1080 x 2340 px Display                                    3
# 6.44 inches, 1080 x 2400 px, 120 Hz Display with Water Drop Notch     3
# 6.43 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole           3
# 6.6 inches, 1080 x 2408 px, 90 Hz Display with Punch Hole             3
# 7.1 inches, 1792 x 1920 px, 120 Hz Display with Punch Hole            3
# 6.6 inches, 1080 x 2412 px, 90 Hz Display with Punch Hole             3
# 6.78 inches, 1440 x 3200 px, 144 Hz Display with Punch Hole           3
# 8.03 inches, 1916 x 2160 px, 120 Hz Display                           3
# 6.1 inches, 1179 x 2556 px, 120 Hz Display                            3
# 6.6 inches, 1080 x 2340 px, 120 Hz Display with Punch Hole            3
# 6.1 inches, 1080 x 2340 px, 120 Hz Display with Punch Hole            3
# 6.7 inches, 1284 x 2778 px Display with Small Notch                   3
# 6.44 inches, 1080 x 2408 px Display with Water Drop Notch             3
# 6.51 inches, 1600 x 720 px Display with Punch Hole                    3
# 6.59 inches, 1080 x 2412 px, 90 Hz Display with Punch Hole            3
# 6.47 inches, 1080 x 2400 px Display with Punch Hole                   3
# 6.44 inches, 1080 x 2400 px, 90 Hz Display with Water Drop Notch      3
# 6.8 inches, 1440 x 3080 px, 120 Hz Display with Punch Hole            3
# 6.22 inches, 1520 x 720 px Display with Water Drop Notch              2
# 6.1 inches, 1080 x 2520 px, 120 Hz Display                            2
# 6.6 inches, 1080 x 2412 px, 144 Hz Display with Punch Hole            2
# 5.45 inches, 720 x 1440 px Display                                    2
# 6.5 inches, 1080 x 2400 px Display with Water Drop Notch              2
# 6 inches, 1080 x 2160 px Display                                      2
# 6.67 inches, 1220 x 2712 px, 120 Hz Display with Punch Hole           2
# 6.8 inches, 1440 x 3200 px, 120 Hz Display with Punch Hole            2
# 6.5 inches, 1644 x 3840 px, 120 Hz Display                            2
# 6.44 inches, 1080 x 2400 px Display with Small Notch                  2
# 6.3 inches, 1080 x 2340 px Display with Water Drop Notch              2
# 6.5 inches, 720 x 1560 px Display with Small Notch                    2
# 6.73 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole           2
# 6.28 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole           2
# 6.8 inches, 1440 x 3040 px Display with Punch Hole                    2
# 5.5 inches, 1080 x 1920 px Display                                    2
# 6.5 inches, 1080 x 2400 px Display with Punch Hole                    2
# 6.4 inches, 1080 x 2340 px Display with Punch Hole                    2
# 6.22 inches, 720 x 1520 px Display with Water Drop Notch              2
# 6.6 inches, 1612 x 720 px Display with Water Drop Notch               2
# 6.18 inches, 1080 x 2246 px Display with Large Notch                  2
# 6.71 inches, 1440 x 3200 px, 120 Hz Display with Punch Hole           2
# 6.4 inches, 720 x 1600 px, 90 Hz Display with Water Drop Notch        2
# 6.58 inches, 1080 x 2408 px, 90 Hz Display with Punch Hole            2
# 6.71 inches, 720 x 1650 px Display with Water Drop Notch              2
# 6.7 inches, 1080 x 2388 px, 90 Hz Display with Punch Hole             2
# 6.57 inches, 1080 x 2340 px, 120 Hz Display with Punch Hole           2
# 6.5 inches, 720 x 1600 px Display with Punch Hole                     2
# 6.8 inches, 1080 x 2460 px Display                                    2
# 6 inches, 720 x 1440 px Display                                       2
# 6.51 inches, 720 x 1600 px Display with Punch Hole                    2
# 6.44 inches, 1080 x 2400 px, 90 Hz Display with Dual Punch Hole       2
# 6.49 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole            2
# 7.6 inches, 1812 x 2176 px, 120 Hz Display with Punch Hole            2
# 6.7 inches, 1080 x 2340 px, 90 Hz Display with Punch Hole             2
# 6.55 inches, 720 x 1612 px Display with Water Drop Notch              2
# 6.7 inches, 1080 x 2400 px, 144 Hz Display with Punch Hole            2
# 6.6 inches, 1080 x 2400 px, 120 Hz Display with Water Drop Notch      2
# 6.56 inches, 720 x 1600 px, 90 Hz Display with Water Drop Notch       2
# 6.56 inches, 1080 x 2376 px, 90 Hz Display with Small Notch           2
# 6.78 inches, 1260 x 2800 px, 120 Hz Display with Punch Hole           2
# 6.72 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole           2
# 6.4 inches, 1080 x 2340 px, 120 Hz Display with Punch Hole            2
# 6.1 inches, 828 x 1792 px Display with Large Notch                    2
# 6.44 inches, 1080 x 2400 px, 90 Hz Display with Small Notch           2
# 6.71 inches, 1440 x 3120 px, 120 Hz Display with Punch Hole           2
# 6.82 inches, 720 x 1600 px, 90 Hz Display with Water Drop Notch       2
# 6.6 inches, 2408 x 1080 px Display with Water Drop Notch              2
# 6.58 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole           2
# 6.7 inches, 1080 x 2640 px, 120 Hz Display with Punch Hole            2
# 6.73 inches, 1080 x 2400 px, 144 Hz Display with Punch Hole           2
# 6.5 inches, 1080 x 2400 px, 144 Hz Display with Punch Hole            2
# 6.6 inches, 1080 x 2400 px Display with Water Drop Notch              2
# 6.78 inches, 1080 x 2480 px, 90 Hz Display with Punch Hole            1
# 6 inches, 720 x 1600 px Display                                       1
# 6.7 inches, 1440 x 3200 px, 120 Hz Display with Punch Hole            1
# 6.71 inches, 1080 x 2400 px Display with Punch Hole                   1
# 6.6 inches, 1080 x 2400 px, 90 Hz Display with Dual Punch Hole        1
# 6.58 inches, 1200 x 2640 px, 90 Hz Display with Dual Punch Hole       1
# 6.39 inches, 1080 x 2316 px Display                                   1
# 6.3 inches, 1080 x 2280 px Display                                    1
# 4 inches, 480 x 640 px Display                                        1
# 6.2 inches, 1440 x 2960 px Display                                    1
# 6.6 inches, 1260 x 2730 px, 240 Hz Display with Punch Hole            1
# 6.78 inches, 1080 x 2460 px Display with Water Drop Notch             1
# 6.73 inches, 1080 x 2408 px, 120 Hz Display with Punch Hole           1
# 6.8 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole             1
# 8.01 inches, 1860 x 2480 px, 90 Hz Display                            1
# 6.51 inches, 1600 x 720 px, 90 Hz Display with Water Drop Notch       1
# 6.5 inches, 1080 x 2400 px, 144 Hz Display                            1
# 6.8 inches, 720 x 1600 px Display with Punch Hole                     1
# 6.67 inches, 1220 x 2712 px, 144 Hz Display with Punch Hole           1
# 6.5 inches, 1080 x 2412 px, 144 Hz Display                            1
# 6.43 inches, 1080 x 2340 px, 90 Hz Display with Punch Hole            1
# 6.06 inches, 1170 x 2532 px Display with Punch Hole                   1
# 6.82 inches, 720 x 1600 px Display with Water Drop Notch              1
# 7.4 inches, 1440 x 3200 px Display                                    1
# 6.26 inches, 720 x 1600 px Display with Large Notch                   1
# 6.43 inches, 1080 x 2400 px Display with Dual Punch Hole              1
# 6.38 inches, 1080 x 2340 px Display with Water Drop Notch             1
# 6.67 inches, 1080 x 2408 px, 120 Hz Display with Water Drop Notch     1
# 6.76 inches, 1440 x 3200 px, 120 Hz Display with Small Notch          1
# 7.8 inches, 2200 x 2480 px, 120 Hz Display with Punch Hole            1
# 6.62 inches, 1080 x 2412 px, 144 Hz Display with Water Drop Notch     1
# 6.95 inches, 1080 x 2460 px, 120 Hz Display with Punch Hole           1
# 6.67 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole            1
# 6.5 inches, 720 x 1600 px, 90 Hz Display                              1
# 6.1 inches, 720 x 1520 px Display with Water Drop Notch               1
# 6.6 inches, 1288 x 2700 px, 120 Hz Display with Punch Hole            1
# 6.7 inches, 1080 x 2520 px, 90 Hz Display with Punch Hole             1
# 6.44 inches, 1080 x 2400 px Display with Dual Punch Hole              1
# 6.2 inches, 1440 x 3200 px Display with Punch Hole                    1
# 6.78 inches, 1200 x 2652 px, 120 Hz Display with Punch Hole           1
# 6.1 inches, 750 x 1580 px Display                                     1
# 7 inches, 1440 x 3080 px, 120 Hz Display with Punch Hole              1
# 5.3 inches, 720 x 1480 px Display                                     1
# 6.6 inches, 1600 x 720 px Display with Punch Hole                     1
# 6 inches, 1080 x 2520 px, 90 Hz Display                               1
# 6.56 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole           1
# 6.58 inches, 1080 x 2412 px, 120 Hz Display with Water Drop Notch     1
# 6.8 inches, 1080 x 2400 px, 165 Hz Display                            1
# 6.51 inches, 1080 x 2400 px, 144 Hz Display with Punch Hole           1
# 6.4 inches, 720 x 1600 px Display with Water Drop Notch               1
# 6.34 inches, 1080 x 2400 px Display with Punch Hole                   1
# 6.5 inches, 1600 x 720 px, 90 Hz Display with Punch Hole              1
# 6.09 inches, 1520 x 720 px Display with Water Drop Notch              1
# 6.67 inches, 1080 x 2340 px, 90 Hz Display with Punch Hole            1
# 6.5 inches, 720 x 1544 px Display with Water Drop Notch               1
# 6.5 inches, 1440 x 3168 px Display with Water Drop Notch              1
# 6.53 inches, 1176 x 2400 px Display with Large Notch                  1
# 6.4 inches, 720 x 1560 px Display with Punch Hole                     1
# 6.1 inches, 1560 x 720 px Display with Water Drop Notch               1
# 8 inches, 2200 x 2480 px Display                                      1
# 6 inches, 2220 x 1080 px Display                                      1
# 5.2 inches, 720 x 1280 px Display                                     1
# 6.1 inches, 720 x 1560 px Display with Punch Hole                     1
# 6.75 inches, 720 x 1600 px, 90 Hz Display with Water Drop Notch       1
# 6.82 inches, 720 x 1560 px Display with Punch Hole                    1
# 5.86 inches, 720 x 1520 px Display with Large Notch                   1
# 6.43 inches, 1440 x 3200 px, 120 Hz Display with Punch Hole           1
# 6.6 inches, 1080 x 2400 px, 144 Hz Display                            1
# 6.73 inches, 1440 x 3120 px, 120 Hz Display with Punch Hole           1
# 6.67 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole           1
# 6.67 inches, 1080 x 2340 px, 144 Hz Display with Punch Hole           1
# 6.9 inches, 1080 x 2460 px, 120 Hz Display                            1
# 6.8 inches, 1080 x 2460 px, 90 Hz Display with Punch Hole             1
# 6.4 inches, 1080 x 2408 px Display with Water Drop Notch              1
# 6.53 inches, 1080 x 2340 px Display with Punch Hole                   1
# 6.8 inches, 1440 x 3088 px, 120 Hz Display with Punch Hole            1
# 5.9 inches, 1080 x 2340 px Display with Water Drop Notch              1
# 6.7 inches, 1440 x 3040 px Display                                    1
# 5.84 inches, 1080 x 2280 px Display with Small Notch                  1
# 6.67 inches, 1080 x 2412 px, 120 Hz Display with Water Drop Notch     1
# 6.43 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole           1
# 6.52 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole            1
# 7.2 inches, 1440 x 1920 px Display                                    1
# 6.62 inches, 2400 x 1080 px, 120 Hz Display with Punch Hole           1
# 6.6 inches, 720 x 1612 px Display with Water Drop Notch               1
# 6 inches, 1080 x 2520 px Display                                      1
# 6.95 inches, 1080 x 2460 px Display with Punch Hole                   1
# 6.53 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole            1
# 6.3 inches, 1080 x 2400 px Display with Punch Hole                    1
# 6.52 inches, 720 x 1600 px, 90 Hz Display with Punch Hole             1
# 6.7 inches, 1440 x 3200 px Display with Punch Hole                    1
# 6.39 inches, 1080 x 2340 px Display                                   1
# 5 inches, 1080 x 1920 px Display                                      1
# 6.71 inches, 1284 x 2778 px, 120 Hz Display with Small Notch          1
# 6.83 inches, 1080 x 2460 px, 120 Hz Display with Punch Hole           1
# 6.91 inches, 1080 x 2460 px Display with Punch Hole                   1
# 6.8 inches, 1080 x 2460 px Display with Water Drop Notch              1
# 6.56 inches, 1080 x 2400 px, 90 Hz Display with Water Drop Notch      1
# 6.9 inches, 1400 x 3200 px, 120 Hz Display with Punch Hole            1
# 6.8 inches, 1080 x 2448 px, 165 Hz Display                            1
# 6.95 inches, 1080 x 2460 px, 90 Hz Display with Punch Hole            1
# 6.7 inches, 1440 x 3120 px, 120 Hz Display with Punch Hole            1
# 6.5 inches, 1600 x 720 px, 90 Hz Display with Water Drop Notch        1
# 6.81 inches, 1080 x 2400 px Display with Punch Hole                   1
# 4.7 inches, 1080 x 1920 px Display                                    1
# 6.6 inches, 1440 x 3200 px, 120 Hz Display with Punch Hole            1
# 6.55 inches, 1080 x 2400 px, 144 Hz Display with Punch Hole           1
# 6.06 inches, 1170 x 2532 px, 120 Hz Display with Punch Hole           1
# 6.82 inches, 720 x 1640 px, 90 Hz Display with Water Drop Notch       1
# 6.67 inches, 1080 x 2412 px, 90 Hz Display with Punch Hole            1
# 6.73 inches, 1290 x 2796 px, 120 Hz Display                           1
# 5.9 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole            1
# 6.2 inches, 720 x 1680 px Display                                     1
# 3.54 inches, 640 x 960 px Display                                     1
# 6.1 inches, 720 x 1560 px Display with Water Drop Notch               1
# 7.92 inches, 2088 x 2250 px Display                                   1
# 6.52 inches, 720 x 1600 px, 90 Hz Display with Water Drop Notch       1
# 6.82 inches, 1640 x 720 px, 90 Hz Display with Punch Hole             1
# 6.5 inches, 720 x 1600 px Display with Small Notch                    1
# 6.7 inches, 1080 x 2400 px, 165 Hz Display                            1
# 4.5 inches, 480 x 854 px Display                                      1
# 6.71 inches, 1440 x 3214 px, 120 Hz Display with Punch Hole           1
# 6.7 inches, 720 x 1650 px Display with Punch Hole                     1
# 6.54 inches, 720 x 1560 px Display with Small Notch                   1
# 6.55 inches, 1612 x 720 px, 90 Hz Display with Water Drop Notch       1
# 6.81 inches, 1080 x 2388 px Display                                   1
# 7.8 inches, 1440 x 1920 px Display                                    1
# 6.36 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole           1
# 6.82 inches, 720 x 1640 px, 90 Hz Display with Punch Hole             1
# 5.42 inches, 1080 x 2340 px Display with Punch Hole                   1
# 6.9 inches, 1080 x 2460 px, 90 Hz Display with Punch Hole             1
# 5.4 inches, 1080 x 2340 px Display with Large Notch                   1
# 6.5 inches, 720 x 1600 px, 120 Hz Display with Punch Hole             1
# 6.53 inches, 720 x 1600 px, 90 Hz Display with Punch Hole             1
# 6.2 inches, 1520 x 720 px Display with Water Drop Notch               1
# 6.1 inches, 828 x 1792 px Display                                     1
# 6.78 inches, 1080 x 2400 px Display with Punch Hole                   1
# 6.83 inches, 1200 x 2860 px, 144 Hz Display with Punch Hole           1
# 6.8 inches, 1200 x 2400 px, 120 Hz Display with Punch Hole            1
# 6.9 inches, 1080 x 2460 px, 120 Hz Display with Punch Hole            1
# 6.7 inches, 1080 x 2400 px, 90 Hz Display with Water Drop Notch       1
# 5.7 inches, 1080 x 2280 px Display                                    1
# 6.4 inches, 1440 x 3040 px Display with Punch Hole                    1
# 6.2 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole            1
# 6.3 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole             1
# 8.02 inches, 1914 x 2160 px, 120 Hz Display with Punch Hole           1
# 6.8 inches, 1080 x 2520 px, 120 Hz Display with Punch Hole            1
# 4.7 inches, 750 x 1334 px Display with Large Notch                    1
# 8.03 inches, 1916 x 2160 px, 120 Hz Display with Punch Hole           1
# 6.55 inches, 1080 x 2460 px, 144 Hz Display with Punch Hole           1
# 6.7 inches, 1080 x 2400 px, 120 Hz Display with Water Drop Notch      1
# 6.58 inches, 1080 x 2400 px, 120 Hz Display with Water Drop Notch     1
# 6.7 inches, 1080 x 2460 px, 165 Hz Display with Punch Hole            1
# 6.6 inches, 1080 x 2460 px, 90 Hz Display with Water Drop Notch       1
# 5.5 inches, 720 x 1440 px Display                                     1
# 6.1 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole             1
# 6.14 inches, 1080 x 2400 px Display with Punch Hole                   1
# 6.9 inches, 1440 x 3200 px Display with Punch Hole                    1
# 6.5 inches, 1242 x 2688 px Display with Large Notch                   1
# 6.5 inches, 1080 x 2400 px, 120 Hz Display                            1
# 6.78 inches, 1080 x 2400 px, 120 Hz Display                           1
# 6.78 inches, 1080 x 2460 px, 90 Hz Display with Punch Hole            1
# 7.6 inches, 1768 x 2208 px, 120 Hz Display with Punch Hole            1
# 2.4 inches, 240 x 320 px Display                                      1
# 6.5 inches, 1644 x 3840 px Display                                    1
# 6.76 inches, 1344 x 2772 px, 90 Hz Display with Punch Hole            1
# 6.57 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole           1
# 6.44 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole            1
# 6.73 inches, 1080 x 2448 px, 165 Hz Display                           1
# 6.76 inches, 1344 x 2772 px, 120 Hz Display with Punch Hole           1
# 6.67 inches, 2400 x 1080 px, 144 Hz Display with Punch Hole           1
# 6 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole              1
# 6.5 inches, 1080 x 2340 px Display                                    1
# 5 inches, 720 x 1280 px Display                                       1
# 6.52 inches, 720 x 1560 px Display with Punch Hole                    1
# 6.74 inches, 1212 x 2616 px, 120 Hz Display                           1
# 6 inches, 1080 x 2340 px, 90 Hz Display with Punch Hole               1
# 2.8 inches, 240 x 320 px Display                                      1
# 6.7 inches, 1080 x 2412 px, 120 Hz Display with Water Drop Notch      1
# 6.68 inches, 1284 x 2778 px, 120 Hz Display with Punch Hole           1
# 6.66 inches, 720 x 1600 px, 90 Hz Display with Water Drop Notch       1
# 6.67 inches, 1080 x 2160 px, 90 Hz Display with Punch Hole            1
# 6.8 inches, 1080 x 2400 px, 120 Hz Display                            1
# 6.64 inches, 1080 x 2388 px, 120 Hz Display with Punch Hole           1
# 6.67 inches, 1080 x 2340 px, 120 Hz Display with Punch Hole           1
# 6.28 inches, 1080 x 2280 px Display                                   1
# 6 inches, 1440 x 2880 px Display                                      1
# 6.73 inches, 1440 x 3412 px, 144 Hz Display with Punch Hole           1
# 6.78 inches, 1080 x 2448 px, 144 Hz Display                           1
# 6.58 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole            1
# 6.56 inches, 720 x 1612 px, 90 Hz Display with Punch Hole             1
# 6.8 inches, 1080 x 2460 px, 144 Hz Display with Punch Hole            1
# 6.62 inches, 2408 x 1080 px Display with Punch Hole                   1
# 6.74 inches, 720 x 1600 px Display with Water Drop Notch              1
# 6.78 inches, 1080 x 2388 px, 90 Hz Display with Punch Hole            1
# 6.92 inches, 1080 x 2460 px, 144 Hz Display                           1
# 6.51 inches, 1080 x 2408 px, 144 Hz Display with Punch Hole           1
# 6.2 inches, 1440 x 3200 px, 120 Hz Display with Punch Hole            1
# 6.43 inches, 1080 x 2460 px, 90 Hz Display with Punch Hole            1
# 6.8 inches, 1080 x 2400 px Display with Punch Hole                    1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 982 entries, 0 to 1019
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      982 non-null    int64
#  1   model      982 non-null    object
#  2   price      982 non-null    int32
#  3   rating     879 non-null    float64
#  4   sim        982 non-null    object
#  5   processor  982 non-null    object
#  6   ram        982 non-null    object
#  7   battery    971 non-null    object
#  8   display    982 non-null    object
#  9   camera     982 non-null    object
#  10  card       982 non-null    object
#  11  os         981 non-null    object
# dtypes: float64(1), int32(1), int64(1), object(9)
# memory usage: 128.2+ KB

# %% [markdown]
# # **Data Ascessing - 2**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 982 entries, 0 to 1019
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      982 non-null    int64
#  1   model      982 non-null    object
#  2   price      982 non-null    int32
#  3   rating     879 non-null    float64
#  4   sim        982 non-null    object
#  5   processor  982 non-null    object
#  6   ram        982 non-null    object
#  7   battery    971 non-null    object
#  8   display    982 non-null    object
#  9   camera     982 non-null    object
#  10  card       982 non-null    object
#  11  os         981 non-null    object
# dtypes: float64(1), int32(1), int64(1), object(9)
# memory usage: 128.2+ KB

# %%
df.head(2)
# Out:
#    index                      model  price  rating  \
# 0      2              OnePlus 11 5G  54999    89.0
# 1      3  OnePlus Nord CE 2 Lite 5G  19989    81.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
#
#                               card           os
# 0        Memory Card Not Supported  Android v13
# 1  Memory Card (Hybrid), upto 1 TB  Android v12

# %%
brand_name = df['model'].str.split().str.get(0)

# %%
df.insert(1,'brand_name',brand_name)

# %%
df['brand_name'] = df['brand_name'].str.lower()

# %%
df['sim'].str.contains('5G')
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16      False
# 17       True
# 18       True
# 19      False
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
# 30       True
# 31       True
# 32       True
# 33      False
# 34       True
# 35       True
# 36       True
# 37       True
# 38       True
# 39       True
# 40       True
# 41       True
# 42       True
# 43       True
# 44      False
# 45       True
# 46      False
# 47      False
# 48      False
# 49       True
# 50       True
# 51       True
# 52       True
# 53       True
# 54      False
# 55       True
# 56       True
# 57      False
# 58       True
# 59      False
# 60       True
# 61       True
# 62      False
# 63      False
# 64       True
# 65       True
# 66       True
# 67       True
# 68       True
# 69       True
# 70      False
# 71       True
# 72       True
# 73       True
# 74       True
# 75      False
# 76       True
# 77       True
# 78       True
# 79      False
# 80      False
# 81       True
# 82       True
# 83       True
# 84       True
# 85       True
# 86       True
# 87       True
# 88      False
# 89       True
# 90      False
# 91       True
# 92       True
# 93       True
# 94      False
# 95      False
# 96      False
# 97       True
# 98       True
# 99       True
# 100      True
# 101      True
# 102      True
# 103      True
# 104      True
# 105      True
# 106      True
# 107      True
# 108     False
# 109      True
# 110      True
# 111      True
# 112      True
# 113      True
# 114     False
# 115      True
# 116      True
# 117      True
# 118      True
# 119      True
# 120      True
# 121      True
# 122      True
# 123      True
# 124      True
# 125      True
# 126     False
# 127      True
# 128      True
# 129      True
# 130      True
# 131     False
# 132     False
# 133      True
# 134      True
# 135      True
# 136     False
# 137     False
# 138     False
# 139      True
# 140      True
# 141      True
# 142      True
# 143     False
# 144     False
# 145     False
# 146      True
# 147      True
# 148     False
# 149      True
# 150      True
# 151     False
# 152      True
# 153      True
# 154      True
# 156     False
# 157      True
# 158      True
# 159      True
# 160     False
# 161     False
# 162      True
# 163      True
# 164      True
# 165     False
# 166     False
# 167     False
# 168      True
# 169      True
# 170     False
# 171      True
# 172      True
# 173      True
# 174     False
# 175      True
# 176     False
# 177     False
# 178      True
# 179      True
# 180     False
# 181      True
# 182     False
# 183      True
# 184      True
# 185      True
# 186      True
# 187      True
# 188     False
# 189     False
# 190     False
# 191     False
# 192      True
# 193      True
# 194      True
# 195     False
# 196      True
# 197      True
# 198      True
# 199     False
# 200     False
# 201     False
# 202      True
# 203      True
# 204     False
# 205      True
# 206      True
# 207      True
# 208     False
# 209      True
# 210      True
# 211      True
# 212      True
# 213      True
# 214      True
# 215      True
# 216      True
# 217     False
# 218      True
# 219     False
# 220      True
# 221      True
# 222      True
# 223      True
# 224     False
# 225     False
# 226     False
# 227      True
# 228      True
# 229      True
# 230      True
# 231      True
# 232     False
# 233     False
# 234      True
# 235     False
# 236      True
# 237     False
# 238      True
# 239     False
# 240      True
# 241     False
# 242      True
# 243      True
# 244      True
# 245      True
# 246     False
# 247      True
# 248      True
# 249      True
# 250     False
# 251      True
# 252     False
# 253      True
# 254      True
# 255      True
# 256      True
# 257      True
# 258      True
# 259     False
# 260      True
# 261      True
# 262     False
# 263     False
# 264      True
# 265      True
# 266      True
# 267      True
# 268     False
# 269      True
# 270     False
# 272      True
# 273     False
# 274      True
# 275      True
# 276      True
# 277      True
# 278     False
# 279     False
# 280      True
# 281      True
# 282     False
# 283      True
# 284      True
# 285     False
# 286      True
# 287      True
# 288     False
# 289      True
# 290      True
# 291     False
# 292      True
# 293     False
# 294     False
# 295      True
# 296      True
# 297      True
# 298      True
# 299     False
# 300     False
# 301      True
# 302     False
# 303      True
# 304     False
# 305      True
# 306      True
# 307      True
# 308      True
# 309     False
# 310      True
# 311      True
# 312      True
# 313      True
# 314      True
# 315     False
# 316      True
# 317      True
# 318      True
# 319      True
# 320      True
# 321      True
# 322      True
# 323      True
# 324      True
# 325     False
# 326      True
# 327     False
# 328      True
# 329     False
# 330     False
# 331      True
# 332      True
# 333      True
# 334      True
# 335      True
# 336     False
# 337     False
# 338     False
# 339      True
# 340     False
# 341     False
# 342      True
# 343     False
# 344     False
# 345      True
# 346      True
# 347      True
# 348      True
# 349      True
# 350     False
# 351     False
# 352     False
# 353     False
# 354      True
# 355     False
# 356     False
# 357     False
# 358     False
# 359      True
# 360     False
# 361      True
# 362      True
# 363      True
# 364      True
# 365      True
# 366      True
# 367     False
# 368      True
# 369      True
# 370      True
# 371      True
# 372     False
# 373     False
# 374     False
# 375     False
# 377      True
# 378     False
# 379      True
# 380      True
# 381     False
# 382     False
# 383     False
# 384     False
# 385      True
# 386      True
# 387      True
# 388     False
# 389     False
# 390      True
# 391     False
# 392      True
# 393     False
# 394     False
# 395      True
# 396     False
# 397      True
# 398      True
# 399     False
# 401      True
# 402      True
# 403     False
# 404      True
# 405     False
# 406      True
# 407      True
# 408      True
# 409      True
# 410      True
# 411      True
# 412      True
# 413     False
# 414      True
# 415      True
# 416      True
# 417      True
# 418     False
# 419      True
# 420      True
# 421      True
# 422      True
# 423      True
# 424      True
# 425      True
# 426      True
# 427     False
# 428      True
# 429      True
# 430     False
# 431     False
# 432     False
# 433     False
# 434      True
# 435      True
# 436     False
# 437     False
# 438     False
# 439      True
# 440     False
# 441     False
# 442     False
# 443     False
# 444     False
# 445      True
# 446      True
# 447     False
# 448      True
# 449     False
# 450     False
# 451      True
# 452     False
# 453     False
# 454     False
# 455     False
# 456      True
# 457     False
# 458      True
# 459     False
# 460     False
# 461     False
# 462      True
# 463      True
# 464      True
# 465     False
# 466     False
# 467     False
# 468      True
# 469      True
# 470      True
# 471     False
# 472      True
# 474     False
# 475      True
# 476     False
# 477     False
# 478     False
# 479     False
# 480     False
# 481     False
# 482      True
# 483     False
# 484      True
# 485     False
# 486     False
# 487      True
# 488     False
# 489      True
# 490     False
# 491     False
# 492     False
# 493      True
# 494     False
# 495      True
# 496     False
# 497      True
# 498      True
# 499      True
# 500      True
# 501     False
# 502     False
# 503     False
# 504      True
# 505     False
# 506     False
# 507     False
# 508      True
# 509     False
# 510     False
# 511     False
# 512      True
# 513      True
# 514      True
# 515      True
# 516      True
# 517      True
# 518     False
# 519      True
# 520      True
# 521     False
# 522     False
# 523      True
# 524     False
# 525      True
# 526      True
# 527      True
# 528     False
# 529     False
# 530     False
# 531     False
# 534      True
# 535      True
# 536     False
# 537     False
# 538     False
# 539     False
# 540      True
# 541      True
# 542     False
# 543     False
# 544      True
# 545      True
# 546      True
# 547      True
# 548      True
# 549      True
# 550      True
# 552      True
# 553     False
# 554      True
# 555     False
# 556     False
# 557      True
# 558     False
# 559      True
# 560      True
# 561      True
# 562     False
# 563     False
# 564     False
# 565      True
# 566      True
# 567      True
# 568      True
# 569      True
# 570      True
# 571     False
# 572     False
# 574     False
# 576     False
# 577      True
# 578     False
# 579      True
# 580      True
# 581     False
# 583      True
# 584      True
# 585      True
# 586     False
# 587     False
# 588     False
# 589     False
# 590     False
# 591      True
# 592      True
# 593      True
# 594      True
# 595     False
# 596     False
# 597     False
# 598     False
# 599      True
# 600     False
# 601      True
# 602     False
# 603     False
# 604     False
# 605      True
# 606     False
# 607     False
# 609     False
# 610     False
# 612     False
# 613     False
# 614      True
# 615      True
# 616      True
# 617      True
# 618     False
# 619     False
# 620      True
# 621     False
# 622     False
# 623      True
# 624     False
# 625     False
# 626      True
# 627     False
# 628      True
# 629      True
# 630      True
# 631     False
# 632     False
# 633     False
# 634      True
# 635     False
# 636      True
# 637      True
# 638     False
# 639      True
# 641      True
# 642      True
# 643      True
# 644     False
# 646      True
# 648     False
# 649     False
# 650     False
# 651      True
# 652      True
# 653      True
# 654      True
# 655     False
# 656     False
# 658     False
# 659      True
# 660      True
# 661      True
# 662     False
# 663     False
# 664      True
# 666     False
# 667     False
# 668      True
# 669      True
# 670     False
# 671     False
# 672     False
# 673     False
# 674     False
# 675      True
# 676      True
# 677     False
# 678     False
# 679      True
# 680      True
# 681     False
# 682      True
# 683     False
# 684      True
# 686      True
# 687     False
# 688      True
# 689     False
# 690     False
# 691      True
# 692      True
# 693      True
# 694     False
# 695     False
# 696      True
# 697     False
# 698      True
# 700      True
# 701     False
# 702      True
# 703      True
# 704      True
# 705     False
# 706     False
# 707     False
# 708     False
# 709     False
# 710      True
# 711     False
# 712     False
# 713     False
# 714      True
# 715     False
# 716     False
# 717     False
# 718     False
# 719      True
# 720      True
# 721      True
# 722      True
# 723      True
# 724      True
# 725     False
# 726     False
# 727      True
# 728     False
# 729     False
# 730     False
# 731      True
# 732      True
# 733     False
# 734     False
# 735     False
# 736     False
# 737      True
# 738     False
# 739      True
# 740      True
# 741      True
# 742      True
# 743     False
# 744     False
# 745      True
# 746      True
# 747     False
# 749      True
# 750     False
# 751     False
# 752     False
# 753     False
# 755     False
# 756     False
# 758     False
# 759      True
# 760      True
# 761      True
# 762      True
# 763     False
# 764      True
# 765      True
# 766      True
# 767      True
# 768      True
# 769      True
# 770      True
# 771     False
# 772     False
# 773     False
# 774      True
# 775     False
# 776      True
# 777      True
# 778     False
# 779     False
# 780     False
# 781      True
# 782     False
# 783     False
# 784     False
# 785      True
# 786     False
# 787     False
# 788     False
# 789      True
# 790      True
# 791      True
# 792     False
# 793     False
# 794     False
# 795     False
# 796      True
# 797     False
# 798     False
# 799     False
# 800      True
# 801     False
# 802     False
# 803     False
# 804     False
# 805     False
# 806      True
# 807      True
# 808     False
# 809      True
# 810      True
# 811     False
# 812      True
# 813      True
# 814      True
# 815      True
# 816     False
# 818     False
# 819      True
# 820     False
# 821     False
# 822      True
# 823     False
# 824     False
# 825      True
# 826      True
# 827      True
# 828      True
# 829     False
# 830     False
# 831      True
# 832      True
# 833     False
# 834     False
# 836      True
# 837     False
# 838     False
# 839     False
# 840      True
# 841     False
# 842      True
# 843      True
# 844     False
# 845     False
# 847      True
# 848      True
# 849      True
# 850     False
# 851      True
# 853      True
# 854     False
# 855     False
# 856     False
# 858      True
# 859     False
# 860     False
# 861     False
# 862     False
# 863     False
# 864     False
# 865     False
# 866     False
# 867     False
# 868     False
# 869     False
# 870      True
# 871     False
# 872     False
# 874      True
# 875     False
# 876      True
# 877      True
# 878     False
# 879      True
# 880     False
# 883     False
# 884     False
# 885     False
# 886      True
# 887     False
# 888      True
# 889     False
# 890      True
# 891      True
# 892      True
# 893      True
# 894      True
# 895     False
# 896     False
# 897     False
# 898      True
# 899      True
# 900     False
# 901     False
# 902      True
# 903     False
# 904      True
# 905     False
# 906      True
# 907     False
# 908      True
# 909      True
# 910     False
# 911     False
# 912     False
# 913      True
# 914      True
# 915     False
# 916     False
# 918     False
# 919      True
# 920      True
# 921     False
# 922     False
# 923     False
# 924     False
# 926     False
# 928      True
# 929      True
# 931     False
# 933      True
# 934      True
# 935     False
# 936     False
# 937     False
# 938     False
# 939      True
# 940     False
# 941      True
# 942     False
# 943      True
# 944      True
# 945      True
# 946      True
# 947      True
# 948     False
# 949     False
# 950     False
# 951      True
# 952      True
# 953     False
# 954      True
# 955      True
# 956     False
# 957      True
# 958     False
# 959      True
# 960      True
# 961      True
# 962      True
# 963     False
# 964      True
# 965     False
# 966      True
# 967      True
# 968      True
# 969     False
# 970     False
# 971      True
# 972     False
# 973     False
# 974      True
# 975      True
# 976     False
# 977     False
# 978     False
# 979     False
# 980     False
# 981     False
# 982     False
# 983     False
# 984     False
# 985      True
# 986     False
# 987     False
# 989     False
# 990      True
# 991     False
# 992     False
# 993      True
# 994     False
# 995     False
# 996     False
# 997     False
# 998      True
# 999     False
# 1001     True
# 1002    False
# 1003    False
# 1004     True
# 1005    False
# 1006    False
# 1007     True
# 1008     True
# 1009     True
# 1010    False
# 1011     True
# 1012    False
# 1013     True
# 1014     True
# 1015     True
# 1016     True
# 1017     True
# 1018     True
# 1019     True
# Name: sim, dtype: bool

# %%
has_5g = df['sim'].str.contains('5G')
has_nfc = df['sim'].str.contains('NFC')
has_ir_blaster = df['sim'].str.contains('IR Blaster')

# %%
df.insert(6,'has_5g',has_5g)
df.insert(7,'has_nfc',has_nfc)
df.insert(8,'has_ir_blaster',has_ir_blaster)

# %%
processor_name = df['processor'].str.split(',').str.get(0)
processor_core = df['processor'].str.split(',').str.get(1)
processor_speed = df['processor'].str.split(',').str.get(2)

# %%
df.insert(10,'processor_name',processor_name)
df.insert(11,'processor_core',processor_core)
df.insert(12,'processor_speed',processor_speed)

# %%
df['processor_name'] = processor_name
processor_brand = df['processor_name'].str.split().str.get(0)

# %%
df.insert(10, 'processor_brand', processor_brand)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 982 entries, 0 to 1019
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            982 non-null    int64
#  1   brand_name       982 non-null    object
#  2   model            982 non-null    object
#  3   price            982 non-null    int32
#  4   rating           879 non-null    float64
#  5   sim              982 non-null    object
#  6   has_5g           982 non-null    bool
#  7   has_nfc          982 non-null    bool
#  8   has_ir_blaster   982 non-null    bool
#  9   processor        982 non-null    object
#  10  processor_brand  982 non-null    object
#  11  processor_name   982 non-null    object
#  12  processor_core   966 non-null    object
#  13  processor_speed  928 non-null    object
#  14  ram              982 non-null    object
#  15  battery          971 non-null    object
#  16  display          982 non-null    object
#  17  camera           982 non-null    object
#  18  card             982 non-null    object
#  19  os               981 non-null    object
# dtypes: bool(3), float64(1), int32(1), int64(1), object(14)
# memory usage: 169.4+ KB

# %%
temp_df = df[df['processor_name'].str.contains('Core')][['processor_name', 'processor_core', 'processor_speed']].shift(1, axis=1)

# %%
df.loc[temp_df.index, temp_df.columns] = temp_df.values

# %%
df.sample(6)
# Out:
#       index brand_name                                       model  price  \
# 621     623     realme                 Realme 8i (6GB RAM + 128GB)  13999
# 1018   1020   motorola                        Motorola Moto G91 5G  19990
# 768     770   motorola                         Motorola Edge 40 5G  34999
# 524     526       vivo                                    Vivo Y01   7999
# 245     247     xiaomi  Xiaomi Redmi Note 11T 5G (6GB RAM + 128GB)  16999
# 332     334       iqoo            iQOO Z6 Pro 5G (8GB RAM + 128GB)  23399
#
#       rating                                             sim  has_5g  has_nfc  \
# 621     77.0                  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False
# 1018    80.0         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 768     86.0         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 524     61.0                  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False
# 245     81.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster    True    False
# 332     80.0              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
#
#       has_ir_blaster                                         processor  \
# 621            False          Helio G96, Octa Core, 2.05 GHz Processor
# 1018           False      Snapdragon 695, Octa Core, 2.2 GHz Processor
# 768            False  Snapdragon 7 Gen1, Octa Core, 2.36 GHz Processor
# 524            False           Helio P35, Octa Core, 2.3 GHz Processor
# 245             True   Dimensity  810 5G, Octa Core, 2.4 GHz Processor
# 332            False    Snapdragon  778G, Octa Core, 2.4 GHz Processor
#
#      processor_brand     processor_name processor_core      processor_speed  \
# 621            Helio          Helio G96      Octa Core   2.05 GHz Processor
# 1018      Snapdragon     Snapdragon 695      Octa Core    2.2 GHz Processor
# 768       Snapdragon  Snapdragon 7 Gen1      Octa Core   2.36 GHz Processor
# 524            Helio          Helio P35      Octa Core    2.3 GHz Processor
# 245        Dimensity  Dimensity  810 5G      Octa Core    2.4 GHz Processor
# 332       Snapdragon   Snapdragon  778G      Octa Core    2.4 GHz Processor
#
#                            ram                                  battery  \
# 621   6 GB RAM, 128 GB inbuilt  5000 mAh Battery with 18W Fast Charging
# 1018  6 GB RAM, 128 GB inbuilt      5000 mAh Battery with Fast Charging
# 768   8 GB RAM, 128 GB inbuilt  4200 mAh Battery with 67W Fast Charging
# 524    2 GB RAM, 32 GB inbuilt                         5000 mAh Battery
# 245   6 GB RAM, 128 GB inbuilt  5000 mAh Battery with 33W Fast Charging
# 332   8 GB RAM, 128 GB inbuilt  4700 mAh Battery with 66W Fast Charging
#
#                                                 display  \
# 621   6.6 inches, 1080 x 2412 px, 120 Hz Display wit...
# 1018  6.8 inches, 1080 x 2400 px Display with Punch ...
# 768          6.5 inches, 1080 x 2412 px, 144 Hz Display
# 524   6.51 inches, 720 x 1600 px Display with Water ...
# 245   6.6 inches, 1080 x 2400 px, 90 Hz Display with...
# 332   6.44 inches, 1080 x 2404 px, 90 Hz Display wit...
#
#                                                  camera  \
# 621   50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 1018  108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 768   50 MP + 50 MP + 2 MP Triple Rear & 32 MP Front...
# 524                       8 MP Rear & 5 MP Front Camera
# 245         50 MP + 8 MP Dual Rear & 16 MP Front Camera
# 332   64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
#
#                                     card           os
# 621   Memory Card Supported, upto 256 GB  Android v11
# 1018    Memory Card Supported, upto 1 TB  Android v12
# 768            Memory Card Not Supported  Android v12
# 524     Memory Card Supported, upto 1 TB  Android v11
# 245      Memory Card (Hybrid), upto 1 TB  Android v11
# 332            Memory Card Not Supported  Android v12

# %%
print(df.loc[856])
# Out:
# index                                                858
# brand_name                                       samsung
# model                            Samsung Galaxy A01 Core
# price                                               4999
# rating                                               NaN
# sim                       Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# has_5g                                             False
# has_nfc                                            False
# has_ir_blaster                                     False
# processor          (28 nm), Quad Core, 1.5 GHz Processor
# processor_brand                                      (28
# processor_name                                   (28 nm)
# processor_core                                 Quad Core
# processor_speed                        1.5 GHz Processor
# ram                              1 GB RAM, 16 GB inbuilt
# battery                                 3000 mAh Battery
# display                5.3 inches, 720 x 1480 px Display
# camera                     8 MP Rear & 5 MP Front Camera
# card                               Memory Card Supported
# os                                           Android v10
# Name: 856, dtype: object

# %%
df['processor_brand'] = df['processor_brand'].str.lower()

# %%
df.loc[856, 'processor_name'] = 'Mediatek MT6739'

# %%
df.sample(2)
# Out:
#      index brand_name                 model  price  rating  \
# 795    797     xiaomi  Xiaomi Redmi 9 Power  11499    74.0
# 695    697    infinix   Infinix Note 13 Pro  16999    80.0
#
#                                             sim  has_5g  has_nfc  \
# 795  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster   False    False
# 695              Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False
#
#      has_ir_blaster                                     processor  \
# 795            True  Snapdragon  662 , Octa Core, 2 GHz Processor
# 695           False      Helio  G99, Octa Core, 2.2 GHz Processor
#
#     processor_brand    processor_name processor_core     processor_speed  \
# 795      snapdragon  Snapdragon  662       Octa Core     2 GHz Processor
# 695           helio        Helio  G99      Octa Core   2.2 GHz Processor
#
#                           ram                                   battery  \
# 795   4 GB RAM, 64 GB inbuilt   6000 mAh Battery with 18W Fast Charging
# 695  6 GB RAM, 128 GB inbuilt  5000 mAh Battery with 120W Fast Charging
#
#                                                display  \
# 795  6.53 inches, 1080 x 2340 px Display with Water...
# 695  6.91 inches, 1080 x 2460 px Display with Punch...
#
#                                     camera  \
# 795    48 MP Quad Rear & 8 MP Front Camera
# 695  108 MP Quad Rear & 16 MP Front Camera
#
#                                    card           os
# 795  Memory Card Supported, upto 512 GB  Android v10
# 695  Memory Card Supported, upto 256 GB  Android v12

# %%
df['processor_core'].value_counts()
# Out:
# processor_core
#  Octa Core              866
#  Hexa Core               31
#  Quad Core               31
#  Octa Core Processor     19
# Octa Core Processor       9
#  Hexa Core Processor      8
# Quad Core                 6
# Octa Core                 5
# Name: count, dtype: int64

# %%
'''
df['processor_core'].replace('Octa Core Processor', 'Octa Core', inplace=True)
df['processor_core'].replace('Hexa Core Processor', 'Hexa Core', inplace=True)
'''

# or

# more effective one
df['processor_core'] = df['processor_core'].str.replace('Octa Core Processor','Octa Core').str.replace('Hexa Core Processor','Hexa Core')

# %%
df['processor_core'] = df['processor_core'].str.strip()

# %%
df['processor_core'].replace('Quad Core', 'Quad Core', inplace=True)
# Out:
# C:\Users\Nihal\AppData\Local\Temp\ipykernel_11692\3295247264.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['processor_core'].replace('Quad Core', 'Quad Core', inplace=True)

# %%
df['processor_core'].value_counts()
# Out:
# processor_core
# Octa Core    899
# Hexa Core     39
# Quad Core     37
# Name: count, dtype: int64

# %%
df['processor_speed']  = df['processor_speed'].str.split().str.get(0).str.replace('\u2009', ' ').str.split(' ').str.get(0).astype('float')

# %%
df.head(2)
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor processor_brand  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor      snapdragon
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor      snapdragon
#
#       processor_name processor_core  processor_speed  \
# 0  Snapdragon 8 Gen2      Octa Core              3.2
# 1     Snapdragon 695      Octa Core              2.2
#
#                          ram                                   battery  \
# 0  12 GB RAM, 256 GB inbuilt  5000 mAh Battery with 100W Fast Charging
# 1   6 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
#
#                               card           os
# 0        Memory Card Not Supported  Android v13
# 1  Memory Card (Hybrid), upto 1 TB  Android v12

# %%
ram_capacity = df['ram'].str.split(',').str.get(0).str.findall(r'\b(\d+)\b').str.get(0)

# %%
base_memory = df['ram'].str.split(',').str.get(1).str.strip().str.findall(r'\b(\d+)\b').str.get(0)

# %%
df.insert(15, 'ram_capacity', ram_capacity)

# %%
df.insert(16, 'base_memory', base_memory)

# %%
pd.set_option('display.max_rows', None)

# %%
df.head(2)
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ... processor_core  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...      Octa Core
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor  ...      Octa Core
#
#   processor_speed                        ram  ram_capacity base_memory  \
# 0             3.2  12 GB RAM, 256 GB inbuilt            12         256
# 1             2.2   6 GB RAM, 128 GB inbuilt             6         128
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
#
#                               card           os
# 0        Memory Card Not Supported  Android v13
# 1  Memory Card (Hybrid), upto 1 TB  Android v12
#
# [2 rows x 22 columns]

# %%
df['ram_capacity'] = df['ram_capacity'].astype(float)

# %%
df.drop([486,627],inplace=True)
df.loc[[483], ['ram_capacity','base_memory']] = [12.0,'512']

# %%
df['base_memory'] = df['base_memory'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 980 entries, 0 to 1019
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            980 non-null    int64
#  1   brand_name       980 non-null    object
#  2   model            980 non-null    object
#  3   price            980 non-null    int32
#  4   rating           879 non-null    float64
#  5   sim              980 non-null    object
#  6   has_5g           980 non-null    bool
#  7   has_nfc          980 non-null    bool
#  8   has_ir_blaster   980 non-null    bool
#  9   processor        980 non-null    object
#  10  processor_brand  980 non-null    object
#  11  processor_name   960 non-null    object
#  12  processor_core   974 non-null    object
#  13  processor_speed  938 non-null    float64
#  14  ram              980 non-null    object
#  15  ram_capacity     980 non-null    float64
#  16  base_memory      978 non-null    float64
#  17  battery          969 non-null    object
#  18  display          980 non-null    object
#  19  camera           980 non-null    object
#  20  card             980 non-null    object
#  21  os               980 non-null    object
# dtypes: bool(3), float64(4), int32(1), int64(1), object(13)
# memory usage: 184.5+ KB

# %%
df['ram_capacity'].value_counts().sort_index(ascending=True)
# Out:
# ram_capacity
# 1.0       7
# 2.0      32
# 3.0      54
# 4.0     215
# 6.0     234
# 8.0     339
# 12.0     86
# 16.0      9
# 18.0      2
# 64.0      2
# Name: count, dtype: int64

# %%
df['base_memory'].value_counts().sort_index(ascending=True)
# Out:
# base_memory
# 1.0        5
# 8.0        1
# 16.0      12
# 32.0      67
# 64.0     191
# 128.0    523
# 256.0    157
# 512.0     22
# Name: count, dtype: int64

# %%
temp_df = df[df['base_memory'] == 1.0]

df.loc[temp_df.index, 'base_memory'] = '1024'
# Out:
# C:\Users\Nihal\AppData\Local\Temp\ipykernel_11692\2153386266.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1024' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[temp_df.index, 'base_memory'] = '1024'

# %%
temp_df = df[df['base_memory'] == '1024']

df.loc[temp_df.index, 'base_memory'] = 1024.0

# %%
df['base_memory'] = df['base_memory'].fillna(0)
df['base_memory'] = df['base_memory'].astype('int')
# Out:
# C:\Users\Nihal\AppData\Local\Temp\ipykernel_11692\137719936.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['base_memory'] = df['base_memory'].fillna(0)

# %%
df['base_memory'].value_counts().sort_index(ascending=True)
# Out:
# base_memory
# 0         2
# 8         1
# 16       12
# 32       67
# 64      191
# 128     523
# 256     157
# 512      22
# 1024      5
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ... processor_core  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...      Octa Core
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor  ...      Octa Core
#
#   processor_speed                        ram  ram_capacity base_memory  \
# 0             3.2  12 GB RAM, 256 GB inbuilt          12.0         256
# 1             2.2   6 GB RAM, 128 GB inbuilt           6.0         128
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
#
#                               card           os
# 0        Memory Card Not Supported  Android v13
# 1  Memory Card (Hybrid), upto 1 TB  Android v12
#
# [2 rows x 22 columns]

# %%
battery_capacity = df['battery'].str.split('with').str.get(0).str.strip().str.findall(r'\b(\d+)\b').str.get(0).astype(float)

# %%
df.drop('battery_capacity', axis=1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[196], line 1
# ----> 1 df.drop('battery_capacity', axis=1, inplace = True)
#
# File E:\Anaconda\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File E:\Anaconda\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File E:\Anaconda\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File E:\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['battery_capacity'] not found in axis"

# %%
df.insert(18,'battery_capacity',battery_capacity)

# %%
fast_charging = df['battery'].str.strip().str.split('with').str.get(1).str.strip().str.findall(r'\d{2,3}')

# %%
df.insert(19, 'fast_charging', fast_charging)

# %%
def fast_charging_function(item):

  if type(item) == list:
    if len(item) == 1:
      return item[0]
    else:
      return 0
  else:
    return -1

# %%
df['fast_charging'] = df['fast_charging'].apply(fast_charging_function).astype(int)

# %%
df.head(2)
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ...  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor  ...
#
#                          ram ram_capacity base_memory  \
# 0  12 GB RAM, 256 GB inbuilt         12.0         256
# 1   6 GB RAM, 128 GB inbuilt          6.0         128
#
#                                     battery battery_capacity  fast_charging  \
# 0  5000 mAh Battery with 100W Fast Charging           5000.0            100
# 1   5000 mAh Battery with 33W Fast Charging           5000.0             33
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
#
#                               card           os
# 0        Memory Card Not Supported  Android v13
# 1  Memory Card (Hybrid), upto 1 TB  Android v12
#
# [2 rows x 24 columns]

# %%
screen_size = df['display'].str.split(',').str.get(0).str.strip().str.split().str.get(0).astype(float)

# %%
resolution = df['display'].str.split(',').str.get(1).str.strip().str.split('px').str.get(0)

# %%
refresh_rate = df['display'].str.split(',').str.get(2).str.strip().str.findall(r'\d{2,3}').str.get(0).apply(lambda x : 60 if pd.isna(x) else x).astype(int)

# %%
df.drop('screen_size', axis=1, inplace = True)
df.drop('resolution', axis=1, inplace = True)
df.drop('refresh_rate', axis=1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[217], line 1
# ----> 1 df.drop('screen_size', axis=1, inplace = True)
#       2 df.drop('resolution', axis=1, inplace = True)
#       3 df.drop('refresh_rate', axis=1, inplace = True)
#
# File E:\Anaconda\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File E:\Anaconda\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File E:\Anaconda\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File E:\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['screen_size'] not found in axis"

# %%
df.insert(21, 'screen_size', screen_size)

# %%
df.insert(22, 'resolution', resolution)

# %%
df.insert(23, 'refresh_rate', refresh_rate)

# %%
df.head(2)
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ...  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor  ...
#
#                                     battery battery_capacity fast_charging  \
# 0  5000 mAh Battery with 100W Fast Charging           5000.0           100
# 1   5000 mAh Battery with 33W Fast Charging           5000.0            33
#
#                                              display screen_size  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...        6.70
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...        6.59
#
#      resolution  refresh_rate  \
# 0  1440 x 3216            120
# 1  1080 x 2412            120
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
#
#                               card           os
# 0        Memory Card Not Supported  Android v13
# 1  Memory Card (Hybrid), upto 1 TB  Android v12
#
# [2 rows x 27 columns]

# %%
def camera_function(val):

  if 'Quad' in val:
    return '4'
  elif 'Triple' in val:
    return '3'
  elif 'Dual' in val:
    return '2'
  elif 'Missing' in val:
    return 'Missing'
  else:
    return '1'

# %%
num_rear_cam = df['camera'].str.split('&').str.get(0).str.strip().apply(camera_function)
num_front_cam = df['camera'].str.split('&').str.get(1).str.strip().fillna('Missing').apply(camera_function)

# %%
df.insert(25, 'num_rear_cam', num_rear_cam)

# %%
df.insert(26, 'num_front_cam', num_front_cam)

# %%
df.head(2)
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ... fast_charging  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...           100
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor  ...            33
#
#                                              display screen_size  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...        6.70
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...        6.59
#
#      resolution refresh_rate  \
# 0  1440 x 3216           120
# 1  1080 x 2412           120
#
#                                               camera  num_rear_cam  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...             3
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...             3
#
#   num_front_cam                             card           os
# 0             1        Memory Card Not Supported  Android v13
# 1             1  Memory Card (Hybrid), upto 1 TB  Android v12
#
# [2 rows x 29 columns]

# %%
df.loc[69,'camera']
# Out:
# 'Foldable Display, Dual Display'

# %%
temp_df = df[df['camera'] == 'Foldable Display, Dual Display']

# %%
df.loc[temp_df.index, 'camera'] = '50 MP'

# %%
df['num_front_cam'].value_counts()
# Out:
# num_front_cam
# 1          947
# 2           29
# Missing      4
# Name: count, dtype: int64

# %%
df['primary_camera_rear'] = df['camera'].str.split(' ').str.get(0).str.replace('\u2009',' ').str.split(' ').str.get(0)

# %%
df['primary_camera_front'] = df['camera'].str.split('&').str.get(1).str.strip().str.split(' ').str.get(0).str.replace('\u2009',' ').str.split(' ').str.get(0)

# %%
df[df['card'] == 'Memory Card (Hybrid)']
# Out:
#      index brand_name                                      model  price  \
# 25      27    samsung                   Samsung Galaxy S20 FE 5G  31239
# 80      82   motorola                       Motorola Moto G72 4G  15999
# 147    149    samsung                      Samsung Galaxy M34 5G  16999
# 151    153   motorola                          Motorola Moto G52  11999
# 178    180       vivo                                Vivo Y75 5G  21990
# 204    206   motorola        Motorola Moto G52 (6GB RAM + 128GB)  12999
# 248    250   motorola                          Motorola Moto G73  25999
# 254    256     xiaomi                Xiaomi Redmi Note 11 Pro 5G  17990
# 281    283       vivo                               Vivo V23e 5G  21994
# 305    307     xiaomi                    Xiaomi Mi 11 Lite NE 5G  21890
# 441    443       poco                                Poco X3 Pro  19650
# 470    472     xiaomi  Xiaomi Mi 11 Lite NE 5G (8GB RAM + 128GB)  22999
# 487    489       sony                           Sony Xperia 5 II  69990
# 489    491       sony        Sony Xperia 1 IV (12GB RAM + 512GB)  92980
# 513    515     realme                               Realme Q5 5G  14990
# 580    582      nokia                                  Nokia G60  28498
# 602    604       vivo                                   Vivo V21  24999
# 626    628       vivo                                Vivo V21 5G  23994
# 629    631       sony                           Sony Xperia 1 II  69999
# 662    664       vivo                                  Vivo V25e  19990
# 680    682         lg                               LG Velvet 5G  54999
# 696    698      honor                              Honor Play 30   9999
# 698    700       sony                        Sony Xperia 5 IV 5G  82199
# 720    722       vivo                                  Vivo V21s  29999
# 767    769   motorola                       Motorola Moto G52 5G  16999
# 860    862       sony                          Sony Xperia 10 II  27999
# 875    877     huawei                            Huawei Nova Y61  21990
# 939    941        zte                               ZTE Axon 30S  19999
# 940    942      honor                                   Honor X6  13999
# 942    944        tcl                                  TCL Ion X   8990
#
#      rating                                                sim  has_5g  \
# 25     88.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 80     83.0                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC   False
# 147    84.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 151    75.0                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC   False
# 178    82.0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True
# 204    79.0                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC   False
# 248    85.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 254    81.0     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster    True
# 281    84.0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True
# 305    83.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True
# 441    82.0         Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster   False
# 470    86.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True
# 487    86.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 489     NaN            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 513    78.0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True
# 580    81.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 602    83.0                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False
# 626    85.0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True
# 629    89.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 662    84.0                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False
# 680    85.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 696    68.0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True
# 698    89.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 720    86.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 767    76.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 860    75.0                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC   False
# 875    63.0                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False
# 939    82.0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True
# 940    71.0                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False
# 942    60.0                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False
#
#      has_nfc  has_ir_blaster                                        processor  \
# 25      True           False    Snapdragon 865, Octa Core, 2.84 GHz Processor
# 80      True           False         Helio  G99, Octa Core, 2.2 GHz Processor
# 147     True           False        Exynos 1200, Octa Core, 2.4 GHz Processor
# 151     True           False     Snapdragon 680, Octa Core, 2.4 GHz Processor
# 178    False           False  Dimensity  700 5G, Octa Core, 2.2 GHz Processor
# 204     True           False     Snapdragon 680, Octa Core, 2.4 GHz Processor
# 248     True           False      Dimensity 930, Octa Core, 2.2 GHz Processor
# 254    False            True     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 281    False           False  Dimensity  810 5G, Octa Core, 2.4 GHz Processor
# 305     True            True  Snapdragon  778G , Octa Core, 2.4 GHz Processor
# 441    False            True    Snapdragon 860, Octa Core, 2.96 GHz Processor
# 470     True            True  Snapdragon  778G , Octa Core, 2.4 GHz Processor
# 487     True           False   Snapdragon 865 , Octa Core, 2.84 GHz Processor
# 489     True           False    Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 513    False           False     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 580     True           False    Snapdragon  695, Octa Core, 2.2 GHz Processor
# 602    False           False     Dimensity 800U, Octa Core, 2.4 GHz Processor
# 626    False           False     Dimensity 800U, Octa Core, 2.4 GHz Processor
# 629     True           False  Snapdragon  865 , Octa Core, 2.84 GHz Processor
# 662    False           False          Helio G99, Octa Core, 2.2 GHz Processor
# 680     True           False   Snapdragon  765G, Octa Core, 2.4 GHz Processor
# 696    False           False    Snapdragon 480+, Octa Core, 2.2 GHz Processor
# 698     True           False    Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 720     True           False    Dimensity 800U , Octa Core, 2.4 GHz Processor
# 767     True           False     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 860     True           False      Snapdragon  665, Octa Core, 2 GHz Processor
# 875    False           False                              Octa Core Processor
# 939     True           False    Snapdragon 870 , Octa Core, 3.2 GHz Processor
# 940    False           False            Helio G25, Octa Core, 2 GHz Processor
# 942    False           False            Helio G25, Octa Core, 2 GHz Processor
#
#      ... screen_size    resolution refresh_rate  \
# 25   ...        6.50  1080 x 2400           120
# 80   ...        6.55  1080 x 2400           120
# 147  ...        6.50  1080 x 2400           120
# 151  ...        6.60  2460 x 1080            90
# 178  ...        6.58  1080 x 2408            60
# 204  ...        6.60  2460 x 1080            90
# 248  ...        6.50  1080 x 2400           120
# 254  ...        6.67  1080 x 2400           120
# 281  ...        6.44  1080 x 2400            60
# 305  ...        6.55  1080 x 2400            90
# 441  ...        6.67  1080 x 2400           120
# 470  ...        6.55  1080 x 2400            90
# 487  ...        6.10  1080 x 2520           120
# 489  ...        6.50  1644 x 3840           120
# 513  ...        6.60  1080 x 2412           120
# 580  ...        6.58  1080 x 2400           120
# 602  ...        6.44  1080 x 2400            90
# 626  ...        6.44  1080 x 2400            90
# 629  ...        6.50  1644 x 3840            60
# 662  ...        6.44  1080 x 2400            90
# 680  ...        6.80  1080 x 2460            60
# 696  ...        6.50   720 x 1600            60
# 698  ...        6.10  1080 x 2520           120
# 720  ...        6.44  1080 x 2400            90
# 767  ...        6.60  2460 x 1080            90
# 860  ...        6.00  1080 x 2520            90
# 875  ...        6.52   720 x 1600            60
# 939  ...        6.90  1080 x 2460           120
# 940  ...        6.50   720 x 1600            60
# 942  ...        6.00   720 x 1440            60
#
#                                                 camera num_rear_cam  \
# 25   12 MP + 12 MP + 8 MP Triple Rear & 32 MP Front...            3
# 80   108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...            3
# 147               64 MP Quad Rear & 32 MP Front Camera            4
# 151  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...            3
# 178  50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...            3
# 204  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...            3
# 248        50 MP + 8 MP Dual Rear & 16 MP Front Camera            2
# 254  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...            3
# 281  50 MP + 8 MP + 2 MP Triple Rear & 44 MP Front ...            3
# 305  64 MP + 8 MP + 5 MP Triple Rear & 20 MP Front ...            3
# 441               48 MP Quad Rear & 20 MP Front Camera            4
# 470  64 MP + 8 MP + 5 MP Triple Rear & 20 MP Front ...            3
# 487  12 MP + 12 MP + 12 MP Triple Rear & 8 MP Front...            3
# 489               12 MP Quad Rear & 12 MP Front Camera            4
# 513  50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...            3
# 580  50 MP + 5 MP + 2 MP Triple Rear & 8 MP Front C...            3
# 602  64 MP + 8 MP + 2 MP Triple Rear & 44 MP Front ...            3
# 626  64 MP + 8 MP + 2 MP Triple Rear & 44 MP Front ...            3
# 629                12 MP Quad Rear & 8 MP Front Camera            4
# 662  64 MP + 2 MP + 2 MP Triple Rear & 32 MP Front ...            3
# 680  48 MP + 8 MP + 5 MP Triple Rear & 16 MP Front ...            3
# 696                     13 MP Rear & 5 MP Front Camera            1
# 698  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...            3
# 720  64 MP + 8 MP + 2 MP Triple Rear & 44 MP Front ...            3
# 767  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...            3
# 860  12 MP + 8 MP + 8 MP Triple Rear & 8 MP Front C...            3
# 875       50 MP + 2 MP Triple Rear & 5 MP Front Camera            3
# 939               50 MP Quad Rear & 16 MP Front Camera            4
# 940  50 MP + 2 MP + 2 MP Triple Rear & 5 MP Front C...            3
# 942                     13 MP Rear & 5 MP Front Camera            1
#
#      num_front_cam                  card             os  primary_camera_rear  \
# 25               1  Memory Card (Hybrid)    Android v10                   12
# 80               1  Memory Card (Hybrid)    Android v12                  108
# 147              1  Memory Card (Hybrid)    Android v12                   64
# 151              1  Memory Card (Hybrid)    Android v12                   50
# 178              1  Memory Card (Hybrid)    Android v12                   50
# 204              1  Memory Card (Hybrid)    Android v12                   50
# 248              1  Memory Card (Hybrid)    Android v13                   50
# 254              1  Memory Card (Hybrid)    Android v11                  108
# 281              1  Memory Card (Hybrid)    Android v12                   50
# 305              1  Memory Card (Hybrid)    Android v11                   64
# 441              1  Memory Card (Hybrid)    Android v11                   48
# 470              1  Memory Card (Hybrid)    Android v11                   64
# 487              1  Memory Card (Hybrid)    Android v10                   12
# 489              1  Memory Card (Hybrid)    Android v12                   12
# 513              1  Memory Card (Hybrid)    Android v12                   50
# 580              1  Memory Card (Hybrid)    Android v12                   50
# 602              1  Memory Card (Hybrid)    Android v11                   64
# 626              1  Memory Card (Hybrid)    Android v11                   64
# 629              1  Memory Card (Hybrid)    Android v10                   12
# 662              1  Memory Card (Hybrid)    Android v12                   64
# 680              1  Memory Card (Hybrid)    Android v10                   48
# 696              1  Memory Card (Hybrid)    Android v11                   13
# 698              1  Memory Card (Hybrid)    Android v12                   12
# 720              1  Memory Card (Hybrid)    Android v12                   64
# 767              1  Memory Card (Hybrid)    Android v12                   50
# 860              1  Memory Card (Hybrid)  Android v10.0                   12
# 875              1  Memory Card (Hybrid)       EMUI v12                   50
# 939              1  Memory Card (Hybrid)    Android v12                   50
# 940              1  Memory Card (Hybrid)    Android v12                   50
# 942              1  Memory Card (Hybrid)        Android                   13
#
#      primary_camera_front
# 25                     32
# 80                     16
# 147                    32
# 151                    16
# 178                    16
# 204                    16
# 248                    16
# 254                    16
# 281                    44
# 305                    20
# 441                    20
# 470                    20
# 487                     8
# 489                    12
# 513                    16
# 580                     8
# 602                    44
# 626                    44
# 629                     8
# 662                    32
# 680                    16
# 696                     5
# 698                    12
# 720                    44
# 767                    16
# 860                     8
# 875                     5
# 939                    16
# 940                     5
# 942                     5
#
# [30 rows x 31 columns]

# %%
import re
def extract_capacity(text):

    match = re.search(r'(\d+)\s*(TB|GB|MB)', text, re.IGNORECASE)
    if match:
        return f"{match.group(1)} {match.group(2).upper()}"
    return '0'

# %%
extended_memory = df['card'].str.strip().apply(extract_capacity)

# %%
df.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ... screen_size  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...        6.70
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor  ...        6.59
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor  ...        6.60
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor  ...        6.55
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor  ...        6.70
#
#      resolution refresh_rate  \
# 0  1440 x 3216           120
# 1  1080 x 2412           120
# 2  1080 x 2408            90
# 3  1080 x 2400           120
# 4  1080 x 2412           120
#
#                                               camera num_rear_cam  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...            3
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...            3
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...            3
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...            3
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...            3
#
#    num_front_cam                              card           os  \
# 0              1         Memory Card Not Supported  Android v13
# 1              1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2              1  Memory Card Supported, upto 1 TB  Android v13
# 3              1   Memory Card (Hybrid), upto 1 TB  Android v12
# 4              1         Memory Card Not Supported  Android v13
#
#    primary_camera_rear  primary_camera_front
# 0                   50                    16
# 1                   64                    16
# 2                   50                    13
# 3                   50                    16
# 4                  108                    16
#
# [5 rows x 31 columns]

# %%
df.insert(28, 'extended_memory', extended_memory)

# %%
temp_df = df[df['os'].str.contains('Memory Card')]

# %%
df.loc[temp_df.index, 'os'] = 'Not Specified'

# %%
print(df['os'].value_counts())
# Out:
# os
# Android v12                        394
# Android v11                        274
# Android v13                         91
# Android v10                         69
# Android v9.0 (Pie)                  29
# Android v10.0                       23
# iOS v16                             15
# Not Specified                       14
# iOS v15                             12
# Android v8.1 (Oreo)                 10
# iOS v14                              6
# iOS v13                              4
# Android v8.0 (Oreo)                  4
# Android v11.0                        4
# iOS v15.0                            3
# EMUI v12                             2
# HarmonyOS v2.0                       2
# Android v5.1.1 (Lollipop)            2
# Android v6.0 (Marshmallow)           2
# Harmony v2.0                         2
# Android v12.1                        2
# iOS v14.0                            2
# HarmonyOS                            1
# Android                              1
# Hongmeng OS v4.0                     1
# Android v7.1 (Nougat)                1
# iOS v17                              1
# iOS v10                              1
# Pragati OS (Powered by Android)      1
# Hongmeng OS v3.0                     1
# Android v5.1 (Lollipop)              1
# Android v4.4.2 (KitKat)              1
# iOS v12.3                            1
# iOS v13.0                            1
# HarmonyOS v2                         1
# Android v9 (Pie)                     1
# Name: count, dtype: int64

# %%
def os_extractor(text):

  if 'Android' in text:
    return 'android'
  elif 'iOS' in text:
    return 'ios'
  elif 'Not Specified':
    return text
  elif 'Harmony' in text or 'Hongmeng' in text or 'EMUI' in text:
    return 'other'

# %%
def r2(text):
  if 'Harmony' in text:
    return 'other'
  elif 'Hongmeng' in text:
    return 'other'
  elif 'Harmony' in text:
    return 'other'
  elif 'EMUI' in text:
    return 'other'
  else:
    return text

# %%
df['os'] = df['os'].str.strip().apply(os_extractor)

# %%
df['os'] = df['os'].apply(r2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 980 entries, 0 to 1019
# Data columns (total 32 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 980 non-null    int64
#  1   brand_name            980 non-null    object
#  2   model                 980 non-null    object
#  3   price                 980 non-null    int32
#  4   rating                879 non-null    float64
#  5   sim                   980 non-null    object
#  6   has_5g                980 non-null    bool
#  7   has_nfc               980 non-null    bool
#  8   has_ir_blaster        980 non-null    bool
#  9   processor             980 non-null    object
#  10  processor_brand       980 non-null    object
#  11  processor_name        960 non-null    object
#  12  processor_core        974 non-null    object
#  13  processor_speed       938 non-null    float64
#  14  ram                   980 non-null    object
#  15  ram_capacity          980 non-null    float64
#  16  base_memory           980 non-null    int32
#  17  battery               969 non-null    object
#  18  battery_capacity      969 non-null    float64
#  19  fast_charging         980 non-null    int32
#  20  display               980 non-null    object
#  21  screen_size           980 non-null    float64
#  22  resolution            980 non-null    object
#  23  refresh_rate          980 non-null    int32
#  24  camera                980 non-null    object
#  25  num_rear_cam          980 non-null    object
#  26  num_front_cam         980 non-null    object
#  27  card                  980 non-null    object
#  28  extended_memory       980 non-null    object
#  29  os                    980 non-null    object
#  30  primary_camera_rear   980 non-null    object
#  31  primary_camera_front  976 non-null    object
# dtypes: bool(3), float64(5), int32(4), int64(1), object(19)
# memory usage: 249.5+ KB

# %%
export_df = df.drop(columns=['index','sim','processor','ram','battery','display','camera','card'])

# %%
pd.set_option('display.max_columns',None)
export_df.head()
# Out:
#   brand_name                      model  price  rating  has_5g  has_nfc  \
# 0    oneplus              OnePlus 11 5G  54999    89.0    True     True
# 1    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0    True    False
# 2    samsung      Samsung Galaxy A14 5G  16499    75.0    True    False
# 3   motorola       Motorola Moto G62 5G  14999    81.0    True    False
# 4     realme         Realme 10 Pro Plus  24999    82.0    True    False
#
#    has_ir_blaster processor_brand     processor_name processor_core  \
# 0           False      snapdragon  Snapdragon 8 Gen2      Octa Core
# 1           False      snapdragon     Snapdragon 695      Octa Core
# 2           False          exynos        Exynos 1330      Octa Core
# 3           False      snapdragon    Snapdragon  695      Octa Core
# 4           False       dimensity     Dimensity 1080      Octa Core
#
#    processor_speed  ram_capacity  base_memory  battery_capacity  \
# 0              3.2          12.0          256            5000.0
# 1              2.2           6.0          128            5000.0
# 2              2.4           4.0           64            5000.0
# 3              2.2           6.0          128            5000.0
# 4              2.6           6.0          128            5000.0
#
#    fast_charging  screen_size    resolution  refresh_rate num_rear_cam  \
# 0            100         6.70  1440 x 3216            120            3
# 1             33         6.59  1080 x 2412            120            3
# 2             15         6.60  1080 x 2408             90            3
# 3              0         6.55  1080 x 2400            120            3
# 4             67         6.70  1080 x 2412            120            3
#
#   num_front_cam extended_memory       os primary_camera_rear  \
# 0             1               0  android                  50
# 1             1            1 TB  android                  64
# 2             1            1 TB  android                  50
# 3             1            1 TB  android                  50
# 4             1               0  android                 108
#
#   primary_camera_front
# 0                   16
# 1                   16
# 2                   13
# 3                   16
# 4                   16

# %%
export_df.to_csv('smartphone_cleaned_v2.csv',index=False)
